# %%
import pandas as pd
import os
import csv

# %%
pwd
# Out:
# '/Users/kabrinar/Desktop/data_bootcamp_project1'

# %%
file_one = os.path.join("data", "graduate_earnings_all.csv")

# %%
df = pd.read_csv(file_one)

# %%
df = df.dropna(how='any')

# %%
refined_data_b = df.loc[df["deglevl"]== "Baccalaureate",:]
refined_data_b.head()
# Out:
#     institution_id            institution_name  deglevl_code        deglevl  \
# 9             3658  UNIVERSITY OF TEXAS-AUSTIN             5  Baccalaureate
# 14            3658  UNIVERSITY OF TEXAS-AUSTIN             5  Baccalaureate
# 15            1348    COLORADO SCHOOL OF MINES             5  Baccalaureate
# 17            1348    COLORADO SCHOOL OF MINES             5  Baccalaureate
# 18            1348    COLORADO SCHOOL OF MINES             5  Baccalaureate
#
#     degcip_4dig               ciptitle  grad_cohort grad_cohort_label  \
# 9          1425  PETROLEUM ENGINEERING         2004         2004-2006
# 14         1425  PETROLEUM ENGINEERING         2001         2001-2003
# 15         1425  PETROLEUM ENGINEERING         2004         2004-2006
# 17         1425  PETROLEUM ENGINEERING         2001         2001-2003
# 18         1425  PETROLEUM ENGINEERING         1998         1998-2000
#
#     year_postgrad  p25_earnings  p50_earnings  p75_earnings  cellcount  \
# ...

# %%
refined_data_m = df.loc[df["deglevl"]== "Masters",:]
refined_data_m.head()
# Out:
#     institution_id            institution_name  deglevl_code  deglevl  \
# 29            3658  UNIVERSITY OF TEXAS-AUSTIN             7  Masters
# 33            3658  UNIVERSITY OF TEXAS-AUSTIN             7  Masters
# 37            1348    COLORADO SCHOOL OF MINES             7  Masters
# 46            3658  UNIVERSITY OF TEXAS-AUSTIN             7  Masters
# 47            1350   COLORADO STATE UNIVERSITY             7  Masters
#
#     degcip_4dig                                           ciptitle  \
# 29         5200  BUSINESS, MANAGEMENT, MARKETING, AND RELATED S...
# 33         1100  COMPUTER AND INFORMATION SCIENCES AND SUPPORT ...
# 37         4000                                  PHYSICAL SCIENCES
# 46         1100  COMPUTER AND INFORMATION SCIENCES AND SUPPORT ...
# 47         1100  COMPUTER AND INFORMATION SCIENCES AND SUPPORT ...
#
#     grad_cohort grad_cohort_label  year_postgrad  p25_earnings  p50_earnings  \
# ...

# %%
refined_data_dpp = df.loc[df["deglevl"]== "Doctoral - Professional Practice",:]
refined_data_dpp.head()
# Out:
#     institution_id                     institution_name  deglevl_code  \
# 10           10019   UNIV OF TEXAS SOUTHWESTERN MED CTR            18
# 11            3659         UT HEALTH CENTER-SAN ANTONIO            18
# 12           13956  UNIV OF TEXAS HEALTH SCIENCE CENTER            18
# 13           13976         UNIV OF TEXAS MEDICAL BRANCH            18
# 16            4508        UNIVERSITY OF COLORADO DENVER            18
#
#                              deglevl  degcip_4dig  ciptitle  grad_cohort  \
# 10  Doctoral - Professional Practice         5112  MEDICINE         2001
# 11  Doctoral - Professional Practice         5112  MEDICINE         2001
# 12  Doctoral - Professional Practice         5112  MEDICINE         2001
# 13  Doctoral - Professional Practice         5112  MEDICINE         2001
# 16  Doctoral - Professional Practice         5112  MEDICINE         2001
#
#    grad_cohort_label  year_postgrad  p25_earnings  p50_earnings  p75_earnings  \
# ...

# %%
refined_data_drs = df.loc[df["deglevl"]== "Doctoral - Research/Scholarship", "Doctoral - Professional Practice":]
refined_data_drs.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    4240             try:
# -> 4241                 return self._searchsorted_monotonic(label, side)
#    4242             except ValueError:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _searchsorted_monotonic(self, label, side)
#    4199
# -> 4200         raise ValueError('index must be monotonic increasing or decreasing')
#    4201
#
# ValueError: index must be monotonic increasing or decreasing
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-a3c2e55c4ec4> in <module>()
# ...

# %%
# Out:
#        institution_id                     institution_name  deglevl_code  \
# 1129             1348             COLORADO SCHOOL OF MINES            17
# 1130             1348             COLORADO SCHOOL OF MINES            17
# 1131             1348             COLORADO SCHOOL OF MINES            17
# 1132             1348             COLORADO SCHOOL OF MINES            17
# 1133             1348             COLORADO SCHOOL OF MINES            17
# 1134             1348             COLORADO SCHOOL OF MINES            17
# 1135             1348             COLORADO SCHOOL OF MINES            17
# 1136             1348             COLORADO SCHOOL OF MINES            17
# 1147             1348             COLORADO SCHOOL OF MINES            17
# 1148             1348             COLORADO SCHOOL OF MINES            17
# 1150             1348             COLORADO SCHOOL OF MINES            17
# 1152             1348             COLORADO SCHOOL OF MINES            17
# ...

# %%
len(refined_data_b)
# Out:
# 5814

# %%
len(refined_data_dpp)
# Out:
# 103

# %%
len(refined_data_drs)
# Out:
# 382
