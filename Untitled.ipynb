# %%
import pandas as pd

# %%
import os

# %%
pwd
# Out:
# '/Users/omartrejo/Desktop/project_1/data_bootcamp_project1'

# %%
file_one = os.path.join("data", "graduate_earnings_all.csv")

# %%
df = pd.read_csv(file_one)

# %%
df = df.dropna(how='any')

# %%
df.loc[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [institution_id, institution_name, deglevl_code, deglevl, degcip_4dig, ciptitle, grad_cohort, grad_cohort_label, year_postgrad, p25_earnings, p50_earnings, p75_earnings, cellcount, cell_suppressed, state, system, first_release, last_update, cpi_reportyear]
# Index: []

# %%
df.count()
# Out:
# institution_id       9417
# institution_name     9417
# deglevl_code         9417
# deglevl              9417
# degcip_4dig          9417
# ciptitle             9417
# grad_cohort          9417
# grad_cohort_label    9417
# year_postgrad        9417
# p25_earnings         9417
# p50_earnings         9417
# p75_earnings         9417
# cellcount            9417
# cell_suppressed      9417
# state                9417
# system               9417
# first_release        9417
# last_update          9417
# cpi_reportyear       9417
# dtype: int64

# %%
df['institution_name'].value_counts()
# Out:
# COLORADO STATE UNIVERSITY                   815
# UNIVERSITY OF TEXAS-AUSTIN                  790
# UNIVERSITY OF COLORADO-BOULDER              743
# UNIVERSITY OF TEXAS-ARLINGTON               475
# UNIVERSITY OF TEXAS-SAN ANTONIO             442
# METROPOLITAN STATE UNIVERSITY OF DENVER     435
# UNIVERSITY OF COLORADO DENVER               421
# UNIVERSITY OF NORTHERN COLORADO             415
# UNIVERSITY OF TEXAS-EL PASO                 382
# UNIVERSITY OF TEXAS - PAN AMERICAN          378
# UNIVERSITY OF TEXAS AT DALLAS               299
# UNIV OF COLORADO AT COLO SPRINGS            267
# FRONT RANGE COMMUNITY COLLEGE               255
# COLORADO MESA UNIVERSITY                    221
# UNIVERSITY OF TEXAS AT TYLER                198
# COLORADO STATE UNIVERSITY-PUEBLO            197
# ARAPAHOE COMMUNITY COLLEGE                  187
# PIKES PEAK COMMUNITY COLLEGE                186
# UNIVERSITY OF TEXAS - BROWNSVILLE           186
# RED ROCKS COMMUNITY COLLEGE                 176
# ...

# %%
texas_college_data = df.loc[df["state"]== "TX",:]
texas_college_data.head()
# Out:
#       institution_id                    institution_name  deglevl_code  \
# 7895            3599  UNIVERSITY OF TEXAS - PAN AMERICAN             5
# 7896            3599  UNIVERSITY OF TEXAS - PAN AMERICAN             5
# 7898            3599  UNIVERSITY OF TEXAS - PAN AMERICAN             5
# 7899            3599  UNIVERSITY OF TEXAS - PAN AMERICAN             5
# 7900            3599  UNIVERSITY OF TEXAS - PAN AMERICAN             5
#
#             deglevl  degcip_4dig                         ciptitle  \
# 7895  Baccalaureate          901  COMMUNICATION AND MEDIA STUDIES
# 7896  Baccalaureate          901  COMMUNICATION AND MEDIA STUDIES
# 7898  Baccalaureate          901  COMMUNICATION AND MEDIA STUDIES
# 7899  Baccalaureate          901  COMMUNICATION AND MEDIA STUDIES
# 7900  Baccalaureate          901  COMMUNICATION AND MEDIA STUDIES
#
#       grad_cohort grad_cohort_label  year_postgrad  p25_earnings  \
# 7895         2004         2004-2006              1       25967.0
# ...

# %%
colorado_college_data = df.loc[df["state"]== "CO",:]
colorado_college_data.head()
# Out:
#    institution_id     institution_name  deglevl_code     deglevl  degcip_4dig  \
# 1            1345  ADAMS STATE COLLEGE             3  Associates         2401
# 2            1345  ADAMS STATE COLLEGE             3  Associates         2401
# 3            1345  ADAMS STATE COLLEGE             3  Associates         2401
# 4            1345  ADAMS STATE COLLEGE             3  Associates         2401
# 5            1345  ADAMS STATE COLLEGE             3  Associates         2401
#
#                                             ciptitle  grad_cohort  \
# 1  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...         1996
# 2  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...         1996
# 3  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...         2001
# 4  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...         2001
# 5  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...         2001
#
#   grad_cohort_label  year_postgrad  p25_earnings  p50_earnings  p75_earnings  \
# ...

# %%
reviewed_df = df.loc[:, ["institution_name", "ciptitle", "grad_cohort","state", "p25_earnings", "p50_earnings", "p75_earnings"]]
reviewed_df.head()
# Out:
#       institution_name                                           ciptitle  \
# 1  ADAMS STATE COLLEGE  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...
# 2  ADAMS STATE COLLEGE  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...
# 3  ADAMS STATE COLLEGE  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...
# 4  ADAMS STATE COLLEGE  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...
# 5  ADAMS STATE COLLEGE  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...
#
#    grad_cohort state  p25_earnings  p50_earnings  p75_earnings
# 1         1996    CO       23108.0       34633.0       50141.0
# 2         1996    CO       31990.0       41565.0       68312.0
# 3         2001    CO       17794.0       25774.0       32213.0
# 4         2001    CO       27763.0       36398.0       51928.0
# 5         2001    CO       31012.0       43798.0       64121.0
