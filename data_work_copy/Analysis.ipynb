# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
tx_top_6_bachelor = "tx_top_6.csv"

tx_bachelor_df = pd.read_csv(tx_top_6_bachelor)
tx_bachelor_df.dtypes
# Out:
# State                  object
# Program                object
# College/University     object
# Years Post Grad         int64
# Cohort                  int64
# Average Earnings($)     int64
# dtype: object

# %%
tx_bachelor_df.plot(kind="bar", x="Program", y="Average Earnings($)", grid=True, figsize=(20,10),
              title="TX Top 6 Bachelor Degrees Average Earnings")
plt.show()
