# %%
# %matplotlib inline 

import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
import os 

#import CSV
graduate_csv = "graduate_earnings_all.csv"

graduate_df = pd.read_csv(graduate_csv)

# %%
reduced_graduate_df = graduate_df.loc[(reduced_graduate_df["p25_earnings"] > 0)]
reduced_graduate_df.head(5)
# Out:
#    institution_id     institution_name  deglevl_code     deglevl  degcip_4dig  \
# 1            1345  ADAMS STATE COLLEGE             3  Associates         2401
# 2            1345  ADAMS STATE COLLEGE             3  Associates         2401
# 3            1345  ADAMS STATE COLLEGE             3  Associates         2401
# 4            1345  ADAMS STATE COLLEGE             3  Associates         2401
# 5            1345  ADAMS STATE COLLEGE             3  Associates         2401
#
#                                             ciptitle  grad_cohort  \
# 1  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...         1996
# 2  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...         1996
# 3  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...         2001
# 4  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...         2001
# 5  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...         2001
#
#   grad_cohort_label  year_postgrad  p25_earnings  p50_earnings  p75_earnings  \
# 1         1996-2000              5       23108.0       34633.0       50141.0
# 2         1996-2000             10       31990.0       41565.0       68312.0
# 3         2001-2005              1       17794.0       25774.0       32213.0
# 4         2001-2005              5       27763.0       36398.0       51928.0
# 5         2001-2005             10       31012.0       43798.0       64121.0
#
#    cellcount  cell_suppressed state system  first_release  last_update  \
# 1       73.0                0    CO   cdhe        8242018      8242018
# 2       65.0                0    CO   cdhe        8242018      8242018
# 3       46.0                0    CO   cdhe        8242018      8242018
# 4       79.0                0    CO   cdhe        8242018      8242018
# 5       85.0                0    CO   cdhe        8242018      8242018
#
#    cpi_reportyear
# 1            2016
# 2            2016
# 3            2016
# 4            2016
# 5            2016

# %%
#Create new DF with columns needed for analysis
reduced_graduate_df = graduate_df.loc[:, ["institution_name", "deglevl", "ciptitle","grad_cohort", "grad_cohort_label", "year_postgrad", "p25_earnings", "p50_earnings", "p75_earnings", "state"]]
reduced_graduate_df.head()
# Out:
#       institution_name     deglevl  \
# 0  ADAMS STATE COLLEGE  Associates
# 1  ADAMS STATE COLLEGE  Associates
# 2  ADAMS STATE COLLEGE  Associates
# 3  ADAMS STATE COLLEGE  Associates
# 4  ADAMS STATE COLLEGE  Associates
#
#                                             ciptitle  grad_cohort  \
# 0  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...         1996
# 1  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...         1996
# 2  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...         1996
# 3  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...         2001
# 4  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...         2001
#
#   grad_cohort_label  year_postgrad  p25_earnings  p50_earnings  p75_earnings  \
# 0         1996-2000              1           NaN           NaN           NaN
# 1         1996-2000              5       23108.0       34633.0       50141.0
# 2         1996-2000             10       31990.0       41565.0       68312.0
# 3         2001-2005              1       17794.0       25774.0       32213.0
# 4         2001-2005              5       27763.0       36398.0       51928.0
#
#   state
# 0    CO
# 1    CO
# 2    CO
# 3    CO
# 4    CO

# %%
#Check for null values
reduced_graduate_df.isnull().any()
# Out:
# institution_name     False
# deglevl              False
# ciptitle             False
# grad_cohort          False
# grad_cohort_label    False
# year_postgrad        False
# p25_earnings          True
# p50_earnings          True
# p75_earnings          True
# state                False
# dtype: bool

# %%
#Rename columns
clean_df = reduced_graduate_df.rename(index=str, columns={"institution_name": "College/University", "deglevl": "Degree", "ciptitle": "Program", "grad_cohort": "Cohort", "year_postgrad": "Years Post Grad", "p25_earnings": "25th Percentile Earnings", "p50_earnings": "50th Percentile Earnings", "p75_earnings": "75th Percentile Earnings", "state": "State"})

# %%
#Add Average Earnings column to simplify earnings analysis
clean_df['Average Earnings'] = clean_df[["25th Percentile Earnings", "50th Percentile Earnings", "75th Percentile Earnings"]].apply(np.mean, axis=1)
clean_df.loc[:,"Average Earnings"] = clean_df["Average Earnings"].astype(float).map("${:,.2f}".format)
clean_df.head()


#Final clean DF
new_clean_df = clean_df.loc[:, ["State", "College/University", "Program", "Degree", "Cohort", "Years Post Grad", "Average Earnings"]]
new_clean_df.head(6)
# Out:
#   State   College/University  \
# 0    CO  ADAMS STATE COLLEGE
# 1    CO  ADAMS STATE COLLEGE
# 2    CO  ADAMS STATE COLLEGE
# 3    CO  ADAMS STATE COLLEGE
# 4    CO  ADAMS STATE COLLEGE
# 5    CO  ADAMS STATE COLLEGE
#
#                                              Program      Degree  Cohort  \
# 0  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Associates    1996
# 1  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Associates    1996
# 2  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Associates    1996
# 3  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Associates    2001
# 4  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Associates    2001
# 5  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Associates    2001
#
#    Years Post Grad Average Earnings
# 0                1             $nan
# 1                5       $35,960.67
# 2               10       $47,289.00
# 3                1       $25,260.33
# 4                5       $38,696.33
# 5               10       $46,310.33

# %%
#We are only analyzing the data for Bachelor, Masters, and Doctorates degrees
#Filtered by Bachelors
bachelor_df = new_clean_df.loc[(new_clean_df["Degree"]=="Baccalaureate")]
bachelor_df.head(6)
# Out:
#    State          College/University                Program         Degree  \
# 9     TX  UNIVERSITY OF TEXAS-AUSTIN  PETROLEUM ENGINEERING  Baccalaureate
# 14    TX  UNIVERSITY OF TEXAS-AUSTIN  PETROLEUM ENGINEERING  Baccalaureate
# 15    CO    COLORADO SCHOOL OF MINES  PETROLEUM ENGINEERING  Baccalaureate
# 17    CO    COLORADO SCHOOL OF MINES  PETROLEUM ENGINEERING  Baccalaureate
# 18    CO    COLORADO SCHOOL OF MINES  PETROLEUM ENGINEERING  Baccalaureate
# 19    TX  UNIVERSITY OF TEXAS-AUSTIN  PETROLEUM ENGINEERING  Baccalaureate
#
#     Cohort  Years Post Grad Average Earnings
# 9     2004               10      $329,249.00
# 14    2001               10      $281,868.67
# 15    2004               10      $267,413.33
# 17    2001               10      $261,703.33
# 18    1998               10      $224,510.00
# 19    2007                5      $186,229.00

# %%
#Highest Average Earnings Bachelor Degrees in TX
tx_bachelor_df = bachelor_df.loc[(new_clean_df["State"]=="TX")]
tx_bachelor_df.head(6)
# Out:
#    State          College/University                     Program  \
# 9     TX  UNIVERSITY OF TEXAS-AUSTIN       PETROLEUM ENGINEERING
# 14    TX  UNIVERSITY OF TEXAS-AUSTIN       PETROLEUM ENGINEERING
# 19    TX  UNIVERSITY OF TEXAS-AUSTIN       PETROLEUM ENGINEERING
# 20    TX  UNIVERSITY OF TEXAS-AUSTIN       PETROLEUM ENGINEERING
# 28    TX  UNIVERSITY OF TEXAS-AUSTIN  BUSINESS/COMMERCE, GENERAL
# 30    TX  UNIVERSITY OF TEXAS-AUSTIN  BUSINESS/COMMERCE, GENERAL
#
#            Degree  Cohort  Years Post Grad Average Earnings
# 9   Baccalaureate    2004               10      $329,249.00
# 14  Baccalaureate    2001               10      $281,868.67
# 19  Baccalaureate    2007                5      $186,229.00
# 20  Baccalaureate    2004                5      $187,258.67
# 28  Baccalaureate    2001               10      $175,514.00
# 30  Baccalaureate    2004               10      $193,089.67

# %%
#Highest Average Earnings Bachelor Degrees in CO
co_bachelor_df = bachelor_df.loc[(new_clean_df["State"]=="CO")]
co_bachelor_df.head(6)
# Out:
#    State        College/University                Program         Degree  \
# 15    CO  COLORADO SCHOOL OF MINES  PETROLEUM ENGINEERING  Baccalaureate
# 17    CO  COLORADO SCHOOL OF MINES  PETROLEUM ENGINEERING  Baccalaureate
# 18    CO  COLORADO SCHOOL OF MINES  PETROLEUM ENGINEERING  Baccalaureate
# 21    CO  COLORADO SCHOOL OF MINES  PETROLEUM ENGINEERING  Baccalaureate
# 31    CO  COLORADO SCHOOL OF MINES  PETROLEUM ENGINEERING  Baccalaureate
# 58    CO  COLORADO SCHOOL OF MINES  PETROLEUM ENGINEERING  Baccalaureate
#
#     Cohort  Years Post Grad Average Earnings
# 15    2004               10      $267,413.33
# 17    2001               10      $261,703.33
# 18    1998               10      $224,510.00
# 21    2004                5      $184,320.33
# 31    2007                5      $165,989.33
# 58    2001                5      $149,085.67

# %%
#Filtered by Masters
masters_df = new_clean_df.loc[(new_clean_df["Degree"]=="Masters")]
masters_df.head(6)
# Out:
#    State          College/University  \
# 29    TX  UNIVERSITY OF TEXAS-AUSTIN
# 33    TX  UNIVERSITY OF TEXAS-AUSTIN
# 37    CO    COLORADO SCHOOL OF MINES
# 46    TX  UNIVERSITY OF TEXAS-AUSTIN
# 47    CO   COLORADO STATE UNIVERSITY
# 63    CO    COLORADO SCHOOL OF MINES
#
#                                               Program   Degree  Cohort  \
# 29  BUSINESS, MANAGEMENT, MARKETING, AND RELATED S...  Masters    2001
# 33  COMPUTER AND INFORMATION SCIENCES AND SUPPORT ...  Masters    2001
# 37                                  PHYSICAL SCIENCES  Masters    2001
# 46  COMPUTER AND INFORMATION SCIENCES AND SUPPORT ...  Masters    2006
# 47  COMPUTER AND INFORMATION SCIENCES AND SUPPORT ...  Masters    1996
# 63                                    SOCIAL SCIENCES  Masters    2001
#
#     Years Post Grad Average Earnings
# 29               10      $170,403.67
# 33               10      $166,107.67
# 37               10      $171,280.67
# 46                5      $154,050.67
# 47               10      $151,229.33
# 63               10      $141,780.33

# %%
#Highest Average Earnings Masters Degrees in TX
tx_masters_df = masters_df.loc[(new_clean_df["State"]=="TX")]
tx_masters_df.head(6)
# Out:
#    State             College/University  \
# 29    TX     UNIVERSITY OF TEXAS-AUSTIN
# 33    TX     UNIVERSITY OF TEXAS-AUSTIN
# 46    TX     UNIVERSITY OF TEXAS-AUSTIN
# 66    TX     UNIVERSITY OF TEXAS-AUSTIN
# 72    TX     UNIVERSITY OF TEXAS-AUSTIN
# 78    TX  UNIVERSITY OF TEXAS AT DALLAS
#
#                                               Program   Degree  Cohort  \
# 29  BUSINESS, MANAGEMENT, MARKETING, AND RELATED S...  Masters    2001
# 33  COMPUTER AND INFORMATION SCIENCES AND SUPPORT ...  Masters    2001
# 46  COMPUTER AND INFORMATION SCIENCES AND SUPPORT ...  Masters    2006
# 66  BUSINESS, MANAGEMENT, MARKETING, AND RELATED S...  Masters    2006
# 72                                        ENGINEERING  Masters    2001
# 78                                        ENGINEERING  Masters    2001
#
#     Years Post Grad Average Earnings
# 29               10      $170,403.67
# 33               10      $166,107.67
# 46                5      $154,050.67
# 66                5      $141,895.00
# 72               10      $138,439.67
# 78               10      $132,653.00

# %%
#Highest Average Earnings Masters Degrees in CO
co_masters_df = masters_df.loc[(new_clean_df["State"]=="CO")]
co_masters_df.head(6)
# Out:
#    State              College/University  \
# 37    CO        COLORADO SCHOOL OF MINES
# 47    CO       COLORADO STATE UNIVERSITY
# 63    CO        COLORADO SCHOOL OF MINES
# 64    CO   UNIVERSITY OF COLORADO DENVER
# 68    CO        COLORADO SCHOOL OF MINES
# 79    CO  UNIVERSITY OF COLORADO-BOULDER
#
#                                               Program   Degree  Cohort  \
# 37                                  PHYSICAL SCIENCES  Masters    2001
# 47  COMPUTER AND INFORMATION SCIENCES AND SUPPORT ...  Masters    1996
# 63                                    SOCIAL SCIENCES  Masters    2001
# 64            HEALTH PROFESSIONS AND RELATED PROGRAMS  Masters    1996
# 68                                  PHYSICAL SCIENCES  Masters    1996
# 79  COMPUTER AND INFORMATION SCIENCES AND SUPPORT ...  Masters    2001
#
#     Years Post Grad Average Earnings
# 37               10      $171,280.67
# 47               10      $151,229.33
# 63               10      $141,780.33
# 64               10      $149,856.00
# 68               10      $138,754.00
# 79               10      $137,432.67

# %%
#Filtered by Doctoral Degrees
doctoral_df = new_clean_df.loc[(new_clean_df["Degree"].str.contains("Doctoral"))]
doctoral_df.head(6)
# Out:
#    State                   College/University  \
# 10    TX   UNIV OF TEXAS SOUTHWESTERN MED CTR
# 11    TX         UT HEALTH CENTER-SAN ANTONIO
# 12    TX  UNIV OF TEXAS HEALTH SCIENCE CENTER
# 13    TX         UNIV OF TEXAS MEDICAL BRANCH
# 16    CO        UNIVERSITY OF COLORADO DENVER
# 22    TX           UNIVERSITY OF TEXAS-AUSTIN
#
#                                               Program  \
# 10                                           MEDICINE
# 11                                           MEDICINE
# 12                                           MEDICINE
# 13                                           MEDICINE
# 16                                           MEDICINE
# 22  BUSINESS, MANAGEMENT, MARKETING, AND RELATED S...
#
#                               Degree  Cohort  Years Post Grad Average Earnings
# 10  Doctoral - Professional Practice    2001               10      $295,536.67
# 11  Doctoral - Professional Practice    2001               10      $291,736.67
# 12  Doctoral - Professional Practice    2001               10      $292,377.33
# 13  Doctoral - Professional Practice    2001               10      $279,900.67
# 16  Doctoral - Professional Practice    2001               10      $268,792.00
# 22   Doctoral - Research/Scholarship    2011                1      $174,588.00

# %%
#Highest Average Earnings Doctoral Degrees in TX
tx_doctoral_df = doctoral_df.loc[(new_clean_df["State"]=="TX")]
tx_doctoral_df.head(6)
# Out:
#    State                   College/University  \
# 10    TX   UNIV OF TEXAS SOUTHWESTERN MED CTR
# 11    TX         UT HEALTH CENTER-SAN ANTONIO
# 12    TX  UNIV OF TEXAS HEALTH SCIENCE CENTER
# 13    TX         UNIV OF TEXAS MEDICAL BRANCH
# 22    TX           UNIVERSITY OF TEXAS-AUSTIN
# 23    TX  UNIV OF TEXAS HEALTH SCIENCE CENTER
#
#                                               Program  \
# 10                                           MEDICINE
# 11                                           MEDICINE
# 12                                           MEDICINE
# 13                                           MEDICINE
# 22  BUSINESS, MANAGEMENT, MARKETING, AND RELATED S...
# 23                                           MEDICINE
#
#                               Degree  Cohort  Years Post Grad Average Earnings
# 10  Doctoral - Professional Practice    2001               10      $295,536.67
# 11  Doctoral - Professional Practice    2001               10      $291,736.67
# 12  Doctoral - Professional Practice    2001               10      $292,377.33
# 13  Doctoral - Professional Practice    2001               10      $279,900.67
# 22   Doctoral - Research/Scholarship    2011                1      $174,588.00
# 23  Doctoral - Professional Practice    2006                5      $172,807.67

# %%
#Highest Average Earnings Doctoral Degrees in CO
co_doctoral_df = doctoral_df.loc[(new_clean_df["State"]=="CO")]
co_doctoral_df.head(6)
# Out:
#    State              College/University  \
# 16    CO   UNIVERSITY OF COLORADO DENVER
# 51    CO  UNIVERSITY OF COLORADO-BOULDER
# 56    CO   UNIVERSITY OF COLORADO DENVER
# 61    CO  UNIVERSITY OF COLORADO-BOULDER
# 62    CO  UNIVERSITY OF COLORADO-BOULDER
# 65    CO   UNIVERSITY OF COLORADO DENVER
#
#                                               Program  \
# 16                                           MEDICINE
# 51  BUSINESS, MANAGEMENT, MARKETING, AND RELATED S...
# 56                                           MEDICINE
# 61  COMPUTER AND INFORMATION SCIENCES AND SUPPORT ...
# 62  BUSINESS, MANAGEMENT, MARKETING, AND RELATED S...
# 65                                          DENTISTRY
#
#                               Degree  Cohort  Years Post Grad Average Earnings
# 16  Doctoral - Professional Practice    2001               10      $268,792.00
# 51   Doctoral - Research/Scholarship    2001               10      $153,036.33
# 56  Doctoral - Professional Practice    2006                5      $143,945.67
# 61   Doctoral - Research/Scholarship    2006                5      $152,863.00
# 62   Doctoral - Research/Scholarship    2006                5      $141,572.33
# 65  Doctoral - Professional Practice    2001               10      $146,107.00

# %%
#Highest Average Earnings Bachelor Degrees in TX
tx_bachelor_df = bachelor_df.loc[(new_clean_df["State"]=="TX")]
tx_bachelor_df.head(6)
# Out:
#    State          College/University                     Program  \
# 9     TX  UNIVERSITY OF TEXAS-AUSTIN       PETROLEUM ENGINEERING
# 14    TX  UNIVERSITY OF TEXAS-AUSTIN       PETROLEUM ENGINEERING
# 19    TX  UNIVERSITY OF TEXAS-AUSTIN       PETROLEUM ENGINEERING
# 20    TX  UNIVERSITY OF TEXAS-AUSTIN       PETROLEUM ENGINEERING
# 28    TX  UNIVERSITY OF TEXAS-AUSTIN  BUSINESS/COMMERCE, GENERAL
# 30    TX  UNIVERSITY OF TEXAS-AUSTIN  BUSINESS/COMMERCE, GENERAL
#
#            Degree  Cohort  Years Post Grad Average Earnings
# 9   Baccalaureate    2004               10      $329,249.00
# 14  Baccalaureate    2001               10      $281,868.67
# 19  Baccalaureate    2007                5      $186,229.00
# 20  Baccalaureate    2004                5      $187,258.67
# 28  Baccalaureate    2001               10      $175,514.00
# 30  Baccalaureate    2004               10      $193,089.67

# %%
tx_bachelor2_df = tx_bachelor_df.sort_values("Average Earnings", ascending=False)
tx_bachelor2_df
# Out:
#       State                  College/University  \
# 19957    TX          UNIVERSITY OF TEXAS-AUSTIN
# 16613    TX     UNIVERSITY OF TEXAS-SAN ANTONIO
# 16542    TX     UNIVERSITY OF TEXAS-SAN ANTONIO
# 16541    TX     UNIVERSITY OF TEXAS-SAN ANTONIO
# 16540    TX     UNIVERSITY OF TEXAS-SAN ANTONIO
# 16539    TX     UNIVERSITY OF TEXAS-SAN ANTONIO
# 16538    TX     UNIVERSITY OF TEXAS-SAN ANTONIO
# 16537    TX     UNIVERSITY OF TEXAS-SAN ANTONIO
# 16536    TX   UNIVERSITY OF TEXAS-PERMIAN BASIN
# 16535    TX   UNIVERSITY OF TEXAS-PERMIAN BASIN
# 16533    TX       UNIVERSITY OF TEXAS AT DALLAS
# 16532    TX       UNIVERSITY OF TEXAS AT DALLAS
# 16531    TX       UNIVERSITY OF TEXAS AT DALLAS
# 16530    TX       UNIVERSITY OF TEXAS AT DALLAS
# 16529    TX       UNIVERSITY OF TEXAS AT DALLAS
# 16528    TX       UNIVERSITY OF TEXAS AT DALLAS
# 16527    TX       UNIVERSITY OF TEXAS AT DALLAS
# 16526    TX       UNIVERSITY OF TEXAS AT DALLAS
# 16525    TX       UNIVERSITY OF TEXAS AT DALLAS
# 16524    TX       UNIVERSITY OF TEXAS AT DALLAS
# 16510    TX  UNIVERSITY OF TEXAS - PAN AMERICAN
# 16543    TX     UNIVERSITY OF TEXAS-SAN ANTONIO
# 16544    TX     UNIVERSITY OF TEXAS-SAN ANTONIO
# 16545    TX     UNIVERSITY OF TEXAS-SAN ANTONIO
# 16603    TX       UNIVERSITY OF TEXAS-ARLINGTON
# 16611    TX         UNIVERSITY OF TEXAS-EL PASO
# 16610    TX         UNIVERSITY OF TEXAS-EL PASO
# 16609    TX          UNIVERSITY OF TEXAS-AUSTIN
# 16608    TX       UNIVERSITY OF TEXAS-ARLINGTON
# 16607    TX       UNIVERSITY OF TEXAS-ARLINGTON
# ...     ...                                 ...
# 960      TX          UNIVERSITY OF TEXAS-AUSTIN
# 160      TX  UNIVERSITY OF TEXAS - PAN AMERICAN
# 253      TX          UNIVERSITY OF TEXAS-AUSTIN
# 237      TX          UNIVERSITY OF TEXAS-AUSTIN
# 176      TX  UNIVERSITY OF TEXAS - PAN AMERICAN
# 217      TX          UNIVERSITY OF TEXAS-AUSTIN
# 177      TX          UNIVERSITY OF TEXAS-AUSTIN
# 948      TX       UNIVERSITY OF TEXAS-ARLINGTON
# 1030     TX          UNIVERSITY OF TEXAS-AUSTIN
# 268      TX          UNIVERSITY OF TEXAS-AUSTIN
# 968      TX  UNIV OF TEXAS SOUTHWESTERN MED CTR
# 1497     TX          UNIVERSITY OF TEXAS-AUSTIN
# 1080     TX          UNIVERSITY OF TEXAS-AUSTIN
# 1207     TX          UNIVERSITY OF TEXAS-AUSTIN
# 1013     TX          UNIVERSITY OF TEXAS-AUSTIN
# 235      TX          UNIVERSITY OF TEXAS-AUSTIN
# 941      TX          UNIVERSITY OF TEXAS-AUSTIN
# 990      TX  UNIVERSITY OF TEXAS - PAN AMERICAN
# 946      TX         UNIVERSITY OF TEXAS-EL PASO
# 959      TX          UNIVERSITY OF TEXAS-AUSTIN
# 979      TX       UNIVERSITY OF TEXAS AT DALLAS
# 987      TX       UNIVERSITY OF TEXAS AT DALLAS
# 269      TX          UNIVERSITY OF TEXAS-AUSTIN
# 254      TX  UNIV OF TEXAS SOUTHWESTERN MED CTR
# 1053     TX          UNIVERSITY OF TEXAS-AUSTIN
# 965      TX  UNIVERSITY OF TEXAS - PAN AMERICAN
# 940      TX       UNIVERSITY OF TEXAS-ARLINGTON
# 983      TX         UNIVERSITY OF TEXAS-EL PASO
# 263      TX        UNIV OF TEXAS MEDICAL BRANCH
# 967      TX       UNIVERSITY OF TEXAS-ARLINGTON
#
#                                                  Program         Degree  \
# 19957                             ZOOLOGY/ANIMAL BIOLOGY  Baccalaureate
# 16613  LINGUISTIC, COMPARATIVE, AND RELATED LANGUAGE ...  Baccalaureate
# 16542  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16541  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16540  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16539  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16538  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16537  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16536  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16535  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16533  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16532  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16531  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16530  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16529  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16528  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16527  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16526  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16525  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16524  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16510  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16543  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16544  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16545  LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 16603  LINGUISTIC, COMPARATIVE, AND RELATED LANGUAGE ...  Baccalaureate
# 16611  LINGUISTIC, COMPARATIVE, AND RELATED LANGUAGE ...  Baccalaureate
# 16610  LINGUISTIC, COMPARATIVE, AND RELATED LANGUAGE ...  Baccalaureate
# 16609  LINGUISTIC, COMPARATIVE, AND RELATED LANGUAGE ...  Baccalaureate
# 16608  LINGUISTIC, COMPARATIVE, AND RELATED LANGUAGE ...  Baccalaureate
# 16607  LINGUISTIC, COMPARATIVE, AND RELATED LANGUAGE ...  Baccalaureate
# ...                                                  ...            ...
# 960    LIBERAL ARTS AND SCIENCES, GENERAL STUDIES AND...  Baccalaureate
# 160    ALLIED HEALTH DIAGNOSTIC, INTERVENTION, AND TR...  Baccalaureate
# 253                           BUSINESS/COMMERCE, GENERAL  Baccalaureate
# 237                           BUSINESS/COMMERCE, GENERAL  Baccalaureate
# 176    ALLIED HEALTH DIAGNOSTIC, INTERVENTION, AND TR...  Baccalaureate
# 217          MANAGEMENT INFORMATION SYSTEMS AND SERVICES  Baccalaureate
# 177                                PETROLEUM ENGINEERING  Baccalaureate
# 948                               MECHANICAL ENGINEERING  Baccalaureate
# 1030                                    BIOLOGY, GENERAL  Baccalaureate
# 268                                    CIVIL ENGINEERING  Baccalaureate
# 968    ALLIED HEALTH DIAGNOSTIC, INTERVENTION, AND TR...  Baccalaureate
# 1497           GEOLOGICAL AND EARTH SCIENCES/GEOSCIENCES  Baccalaureate
# 1080           GEOLOGICAL AND EARTH SCIENCES/GEOSCIENCES  Baccalaureate
# 1207      BIOCHEMISTRY, BIOPHYSICS AND MOLECULAR BIOLOGY  Baccalaureate
# 1013                                           ECONOMICS  Baccalaureate
# 235    AEROSPACE, AERONAUTICAL AND ASTRONAUTICAL ENGI...  Baccalaureate
# 941    AEROSPACE, AERONAUTICAL AND ASTRONAUTICAL ENGI...  Baccalaureate
# 990    ALLIED HEALTH DIAGNOSTIC, INTERVENTION, AND TR...  Baccalaureate
# 946    ELECTRICAL, ELECTRONICS AND COMMUNICATIONS ENG...  Baccalaureate
# 959                            ARCHITECTURAL ENGINEERING  Baccalaureate
# 979    ELECTRICAL, ELECTRONICS AND COMMUNICATIONS ENG...  Baccalaureate
# 987    ELECTRICAL, ELECTRONICS AND COMMUNICATIONS ENG...  Baccalaureate
# 269                                 CHEMICAL ENGINEERING  Baccalaureate
# 254    ALLIED HEALTH DIAGNOSTIC, INTERVENTION, AND TR...  Baccalaureate
# 1053                                           ECONOMICS  Baccalaureate
# 965    ALLIED HEALTH DIAGNOSTIC, INTERVENTION, AND TR...  Baccalaureate
# 940    ELECTRICAL, ELECTRONICS AND COMMUNICATIONS ENG...  Baccalaureate
# 983                               MECHANICAL ENGINEERING  Baccalaureate
# 263    ALLIED HEALTH DIAGNOSTIC, INTERVENTION, AND TR...  Baccalaureate
# 967                                 COMPUTER ENGINEERING  Baccalaureate
#
#        Cohort  Years Post Grad Average Earnings
# 19957    2007                5             $nan
# 16613    2013                1             $nan
# 16542    2004               10             $nan
# 16541    2004                5             $nan
# 16540    2004                1             $nan
# 16539    2001               10             $nan
# 16538    2001                5             $nan
# 16537    2001                1             $nan
# 16536    2013                1             $nan
# 16535    2010                1             $nan
# 16533    2013                1             $nan
# 16532    2010                1             $nan
# 16531    2007                5             $nan
# 16530    2007                1             $nan
# 16529    2004               10             $nan
# 16528    2004                5             $nan
# 16527    2004                1             $nan
# 16526    2001               10             $nan
# 16525    2001                5             $nan
# 16524    2001                1             $nan
# 16510    2004               10             $nan
# 16543    2007                1             $nan
# 16544    2007                5             $nan
# 16545    2010                1             $nan
# 16603    2004                5             $nan
# 16611    2013                1             $nan
# 16610    2010                1             $nan
# 16609    2004               10             $nan
# 16608    2013                1             $nan
# 16607    2010                1             $nan
# ...       ...              ...              ...
# 960      2001               10      $113,257.00
# 160      2007                5      $112,724.33
# 253      2001                5      $112,237.67
# 237      2004                5      $111,863.67
# 176      2001                5      $110,933.67
# 217      2001               10      $110,180.33
# 177      2004                1      $108,529.00
# 948      2004               10      $107,442.33
# 1030     2001               10      $107,357.67
# 268      2004               10      $106,983.00
# 968      2001               10      $106,663.00
# 1497     2004               10      $106,118.33
# 1080     2007                5      $105,476.00
# 1207     2001               10      $105,415.00
# 1013     2004               10      $105,002.33
# 235      2004               10      $104,686.33
# 941      2001               10      $104,356.67
# 990      2001                1      $104,250.33
# 946      2001               10      $104,091.00
# 959      2004               10      $103,925.00
# 979      2001               10      $103,569.67
# 987      2004               10      $102,792.67
# 269      2007                5      $102,682.67
# 254      2001                5      $102,266.67
# 1053     2001               10      $101,770.33
# 965      2007                1      $101,663.33
# 940      2001               10      $101,645.33
# 983      2004               10      $101,611.33
# 263      2001               10      $101,505.67
# 967      2004               10      $100,644.33
#
# [4144 rows x 7 columns]

# %%
tx_bachelor_df = tx_bachelor_df.sort_values(["Program", "Average Earnings"], ascending=True)
tx_bachelor_df.head()
# Out:
#      State                  College/University  \
# 93      TX          UNIVERSITY OF TEXAS-AUSTIN
# 77      TX          UNIVERSITY OF TEXAS-AUSTIN
# 8486    TX   UNIVERSITY OF TEXAS - BROWNSVILLE
# 8502    TX   UNIVERSITY OF TEXAS - BROWNSVILLE
# 8250    TX  UNIVERSITY OF TEXAS - PAN AMERICAN
#
#                               Program         Degree  Cohort  Years Post Grad  \
# 93    ACCOUNTING AND RELATED SERVICES  Baccalaureate    2004               10
# 77    ACCOUNTING AND RELATED SERVICES  Baccalaureate    2001               10
# 8486  ACCOUNTING AND RELATED SERVICES  Baccalaureate    2010                1
# 8502  ACCOUNTING AND RELATED SERVICES  Baccalaureate    2004                1
# 8250  ACCOUNTING AND RELATED SERVICES  Baccalaureate    2010                1
#
#      Average Earnings
# 93        $129,976.67
# 77        $136,081.00
# 8486       $34,471.67
# 8502       $36,044.67
# 8250       $37,051.33

# %%
#average earnings for percentile for cohorts (all subjects)

import csv
def makedic(filename):
	f = open(filename, "r")
	reader = csv.reader(f)
	newl = []
	for i in reader:
		line = i
		dic = {}
		dic['id'] = line[0]
		dic['school'] = line[1]
		dic['degree'] = line[3]
		dic['cohort'] = line[6]
		dic['p25'] = line[9]
		dic['p50'] = line[10]
		dic['p75'] = line[11]
		newl.append(dic)
	return newl

def aveCohort(l):
	dic = {}
	for i in l:
		if i['cohort'] in dic.keys():
			try:
				newl = dic[i['cohort']]
				newl[0] = newl[0] + int(i['p25'])
				newl[1] = newl[1] + int(i['p50'])
				newl[2] = newl[2] + int(i['p75'])
				newl[3] = newl[3] + 1
			except:
				pass
		else:
			try:
				newl = []
				newl.append(int(i['p25']))
				newl.append(int(i['p50']))
				newl.append(int(i['p75']))
				newl.append(1)
				dic[i['cohort']] = newl
			except:
				pass
	for i in dic.keys():
		print("cohort: " + i)
		print("the average salary at 25 is:" + str(float(dic[i][0])/dic[i][3]))
		print("the average salary at 50 is:" + str(float(dic[i][1])/dic[i][3]))
		print("the average salary at 75 is:" + str(float(dic[i][2])/dic[i][3]))
		print("\n\n")
	return dic
	

def main():
	filename = 'graduate_earnings_all.csv'
	data = makedic(filename)
	aveCohort(data)
	
main()
# Out:
# cohort: 1996
# the average salary at 25 is:41885.98395721925
# the average salary at 50 is:57129.71122994652
# the average salary at 75 is:76580.4367201426
#
#
#
# cohort: 2001
# the average salary at 25 is:40580.36921494686
# the average salary at 50 is:54823.0301679808
# the average salary at 75 is:73048.87624271512
#
#
#
# cohort: 2006
# the average salary at 25 is:39247.3883029722
# the average salary at 50 is:53216.663470757434
# the average salary at 75 is:70989.57430488974
#
#
#
# cohort: 2011
# the average salary at 25 is:34119.80173913044
# the average salary at 50 is:46387.56695652174
# the average salary at 75 is:61970.51130434783
#
#
#
# cohort: 2004
# the average salary at 25 is:38221.85865257596
# the average salary at 50 is:51141.637384412155
# the average salary at 75 is:67117.81902245707
#
#
#
# cohort: 1998
# the average salary at 25 is:38404.89638157895
# the average salary at 50 is:52381.13651315789
# the average salary at 75 is:69474.74835526316
#
#
#
# cohort: 2007
# the average salary at 25 is:34009.92230347349
# the average salary at 50 is:45298.22212065814
# the average salary at 75 is:58406.531078610606
#
#
#
# cohort: 2013
# the average salary at 25 is:29687.65977443609
# the average salary at 50 is:39636.20864661654
# the average salary at 75 is:51539.75187969925
#
#
#
# cohort: 2010
# the average salary at 25 is:27961.80977312391
# the average salary at 50 is:37358.931937172776
# the average salary at 75 is:48697.64397905759

# %%
import csv
def makedic(filename):
	f = open(filename, "r")
	reader = csv.reader(f)
	newl = []
	for i in reader:
		line = i
		dic = {}
		dic['id'] = line[0]
		dic['school'] = line[1]
		dic['degree'] = line[3]
		dic['cohort'] = line[6]
		dic['p25'] = line[9]
		dic['p50'] = line[10]
		dic['p75'] = line[11]
		newl.append(dic)
	return newl

def aveCohort(l):
	dic = {}
	for i in l:
		if i['cohort'] in dic.keys():
			try:
				newl = dic[i['cohort']]
				newl[0] = newl[0] + int(i['p25'])
				newl[1] = newl[1] + int(i['p50'])
				newl[2] = newl[2] + int(i['p75'])
				newl[3] = newl[3] + 1
			except:
				pass
		else:
			try:
				newl = []
				newl.append(int(i['p25']))
				newl.append(int(i['p50']))
				newl.append(int(i['p75']))
				newl.append(1)
				dic[i['cohort']] = newl
			except:
				pass
	for i in dic.keys():
		print("cohort: " + i)
		print("the average salary at 25 is:" + str(float(dic[i][0])/dic[i][3]))
		print("the average salary at 50 is:" + str(float(dic[i][1])/dic[i][3]))
		print("the average salary at 75 is:" + str(float(dic[i][2])/dic[i][3]))
		print("\n\n")
	return dic

def aveDegree(l):
	dic = {}
	for i in l:
		if i['degree'] in dic.keys():
			try:
				newl = dic[i['degree']]
				newl[0] = newl[0] + int(i['p25'])
				newl[1] = newl[1] + int(i['p50'])
				newl[2] = newl[2] + int(i['p75'])
				newl[3] = newl[3] + 1
			except:
				pass
		else:
			try:
				newl = []
				newl.append(int(i['p25']))
				newl.append(int(i['p50']))
				newl.append(int(i['p75']))
				newl.append(1)
				dic[i['degree']] = newl
			except:
				pass
	for i in dic.keys():
		print("-----------------")
		print("degree: " + i)
		print("the average salary at 25 is:" + str(float(dic[i][0])/dic[i][3]))
		print("the average salary at 50 is:" + str(float(dic[i][1])/dic[i][3]))
		print("the average salary at 75 is:" + str(float(dic[i][2])/dic[i][3]))
		print("\n\n")
		print("\n~COHORT BREAKDOWN:\n")
		aveCohort(isoDegree(l, i))
		print("-----------------")

	return dic

def isoSchool(l, school):
	newl = []
	for i in l:
		if i['id'] == school:
			newl.append(i)
	return newl

def isoDegree(l, degree):
	newl = []
	for i in l:
		if i['degree'] == degree:
			newl.append(i)
	return newl


def getschools(l):
	dic = {}
	for i in l:
		if i['id'] in dic.keys():
			pass
		else:
			dic[i['id']] = i['school']
	return dic

def order(l):
	for i in getschools(l).keys():
		print("===============")
		print("data for: " + getschools(l)[i])
		print("\n~DEGREE BREAKDOWN!:\n")
		aveDegree(isoSchool(l, i))
		print("===============")
		
		
	

def main():
	filename = 'graduate_earnings_all.csv'
	data = makedic(filename)
	order(data)
	
	
main()
# Out:
# ===============
# data for: institution_name
#
# ~DEGREE BREAKDOWN!:
#
# ===============
# ===============
# data for: ADAMS STATE COLLEGE
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Associates
# the average salary at 25 is:23025.875
# the average salary at 50 is:31965.375
# the average salary at 75 is:46262.75
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 1996
# the average salary at 25 is:27549.0
# the average salary at 50 is:38099.0
# the average salary at 75 is:59226.5
#
#
#
# cohort: 2001
# the average salary at 25 is:25523.0
# the average salary at 50 is:35323.333333333336
# the average salary at 75 is:49420.666666666664
#
#
#
# cohort: 2006
# the average salary at 25 is:18808.5
# the average salary at 50 is:26665.0
# the average salary at 75 is:38385.5
#
#
#
# cohort: 2011
# the average salary at 25 is:14923.0
# the average salary at 50 is:20225.0
# the average salary at 75 is:26616.0
#
#
#
# -----------------
# -----------------
# degree: Baccalaureate
# the average salary at 25 is:27869.60606060606
# the average salary at 50 is:37432.106060606064
# the average salary at 75 is:48917.893939393936
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 1998
# the average salary at 25 is:32230.333333333332
# the average salary at 50 is:42919.5
# the average salary at 75 is:57640.88888888889
#
#
#
# cohort: 2004
# the average salary at 25 is:26771.9375
# the average salary at 50 is:36621.875
# the average salary at 75 is:46332.375
#
#
#
# cohort: 2001
# the average salary at 25 is:27749.5625
# the average salary at 50 is:37342.625
# the average salary at 75 is:48796.125
#
#
#
# cohort: 2007
# the average salary at 25 is:25945.555555555555
# the average salary at 50 is:34599.333333333336
# the average salary at 75 is:45500.88888888889
#
#
#
# cohort: 2013
# the average salary at 25 is:23658.333333333332
# the average salary at 50 is:30842.333333333332
# the average salary at 75 is:40506.0
#
#
#
# cohort: 2010
# the average salary at 25 is:20604.75
# the average salary at 50 is:27653.75
# the average salary at 75 is:34490.75
#
#
#
# -----------------
# -----------------
# degree: Masters
# the average salary at 25 is:38747.666666666664
# the average salary at 50 is:47958.27777777778
# the average salary at 75 is:58464.833333333336
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 1996
# the average salary at 25 is:42560.8
# the average salary at 50 is:52154.2
# the average salary at 75 is:64026.0
#
#
#
# cohort: 2001
# the average salary at 25 is:39291.5
# the average salary at 50 is:48412.166666666664
# the average salary at 75 is:58901.333333333336
#
#
#
# cohort: 2006
# the average salary at 25 is:35803.0
# the average salary at 50 is:44720.5
# the average salary at 75 is:53461.0
#
#
#
# cohort: 2011
# the average salary at 25 is:35231.0
# the average salary at 50 is:44374.333333333336
# the average salary at 75 is:54995.0
#
#
#
# -----------------
# ===============
# ===============
# data for: UNIVERSITY OF TEXAS-AUSTIN
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Baccalaureate
# the average salary at 25 is:43366.287769784176
# the average salary at 50 is:58775.203237410075
# the average salary at 75 is:79796.23741007195
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2004
# the average salary at 25 is:47148.70121951219
# the average salary at 50 is:64491.78048780488
# the average salary at 75 is:88933.07926829268
#
#
#
# cohort: 2001
# the average salary at 25 is:46148.1686746988
# the average salary at 50 is:62820.819277108436
# the average salary at 75 is:86870.95180722892
#
#
#
# cohort: 2007
# the average salary at 25 is:41603.27433628318
# the average salary at 50 is:55999.929203539825
# the average salary at 75 is:74199.06194690266
#
#
#
# cohort: 2013
# the average salary at 25 is:36978.0
# the average salary at 50 is:48973.82142857143
# the average salary at 75 is:63433.44642857143
#
#
#
# cohort: 2010
# the average salary at 25 is:34153.245614035084
# the average salary at 50 is:45676.82456140351
# the average salary at 75 is:60076.10526315789
#
#
#
# -----------------
# -----------------
# degree: Doctoral - Research/Scholarship
# the average salary at 25 is:64700.9693877551
# the average salary at 50 is:83695.6836734694
# the average salary at 75 is:108680.19387755102
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2011
# the average salary at 25 is:59352.1875
# the average salary at 50 is:77394.375
# the average salary at 75 is:102132.8125
#
#
#
# cohort: 2006
# the average salary at 25 is:62576.06060606061
# the average salary at 50 is:81168.63636363637
# the average salary at 75 is:106189.30303030302
#
#
#
# cohort: 2001
# the average salary at 25 is:67878.57142857143
# the average salary at 50 is:87455.14285714286
# the average salary at 75 is:112495.6530612245
#
#
#
# -----------------
# -----------------
# degree: Masters
# the average salary at 25 is:46299.68292682927
# the average salary at 50 is:64063.260162601626
# the average salary at 75 is:89085.8861788618
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:50054.28333333333
# the average salary at 50 is:68844.66666666667
# the average salary at 75 is:95225.01666666666
#
#
#
# cohort: 2006
# the average salary at 25 is:43896.69047619047
# the average salary at 50 is:61142.142857142855
# the average salary at 75 is:84499.78571428571
#
#
#
# cohort: 2011
# the average salary at 25 is:40378.23809523809
# the average salary at 50 is:56244.333333333336
# the average salary at 75 is:80717.71428571429
#
#
#
# -----------------
# -----------------
# degree: Doctoral - Professional Practice
# the average salary at 25 is:86654.76923076923
# the average salary at 50 is:125817.15384615384
# the average salary at 75 is:169622.92307692306
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2006
# the average salary at 25 is:91644.5
# the average salary at 50 is:138789.0
# the average salary at 75 is:182263.5
#
#
#
# cohort: 2001
# the average salary at 25 is:90633.83333333333
# the average salary at 50 is:129289.33333333333
# the average salary at 75 is:178288.66666666666
#
#
#
# cohort: 2011
# the average salary at 25 is:72043.66666666667
# the average salary at 50 is:101577.0
# the average salary at 75 is:135437.33333333334
#
#
#
# -----------------
# ===============
# ===============
# data for: UNIV OF TEXAS SOUTHWESTERN MED CTR
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Doctoral - Professional Practice
# the average salary at 25 is:78484.42857142857
# the average salary at 50 is:114483.71428571429
# the average salary at 75 is:165539.57142857142
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:101640.33333333333
# the average salary at 50 is:158813.66666666666
# the average salary at 75 is:244944.0
#
#
#
# cohort: 2006
# the average salary at 25 is:67044.5
# the average salary at 50 is:100464.0
# the average salary at 75 is:142527.0
#
#
#
# cohort: 2011
# the average salary at 25 is:55190.5
# the average salary at 50 is:62008.5
# the average salary at 75 is:69445.5
#
#
#
# -----------------
# -----------------
# degree: Doctoral - Research/Scholarship
# the average salary at 25 is:50216.625
# the average salary at 50 is:67899.0
# the average salary at 75 is:94647.625
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:57688.0
# the average salary at 50 is:79434.25
# the average salary at 75 is:112384.0
#
#
#
# cohort: 2006
# the average salary at 25 is:42609.666666666664
# the average salary at 50 is:58330.666666666664
# the average salary at 75 is:82575.33333333333
#
#
#
# cohort: 2011
# the average salary at 25 is:43152.0
# the average salary at 50 is:50463.0
# the average salary at 75 is:59919.0
#
#
#
# -----------------
# -----------------
# degree: Baccalaureate
# the average salary at 25 is:47850.72727272727
# the average salary at 50 is:62329.36363636364
# the average salary at 75 is:79431.72727272728
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:57221.333333333336
# the average salary at 50 is:75599.44444444444
# the average salary at 75 is:99541.44444444444
#
#
#
# cohort: 2007
# the average salary at 25 is:42828.2
# the average salary at 50 is:54107.6
# the average salary at 75 is:64816.8
#
#
#
# cohort: 2004
# the average salary at 25 is:40393.166666666664
# the average salary at 50 is:53126.333333333336
# the average salary at 75 is:67445.33333333333
#
#
#
# cohort: 2010
# the average salary at 25 is:40612.0
# the average salary at 50 is:50777.5
# the average salary at 75 is:61434.5
#
#
#
# -----------------
# -----------------
# degree: Masters
# the average salary at 25 is:56281.333333333336
# the average salary at 50 is:79286.66666666667
# the average salary at 75 is:105077.5
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2006
# the average salary at 25 is:62169.0
# the average salary at 50 is:85521.0
# the average salary at 75 is:115480.5
#
#
#
# cohort: 2011
# the average salary at 25 is:45500.0
# the average salary at 50 is:80964.0
# the average salary at 75 is:115339.0
#
#
#
# cohort: 2001
# the average salary at 25 is:55950.0
# the average salary at 50 is:74571.33333333333
# the average salary at 75 is:94721.66666666667
#
#
#
# -----------------
# ===============
# ===============
# data for: UT HEALTH CENTER-SAN ANTONIO
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Doctoral - Professional Practice
# the average salary at 25 is:74750.26666666666
# the average salary at 50 is:114278.2
# the average salary at 75 is:165427.33333333334
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:88878.5
# the average salary at 50 is:144037.33333333334
# the average salary at 75 is:220606.66666666666
#
#
#
# cohort: 2006
# the average salary at 25 is:66439.16666666667
# the average salary at 50 is:101316.83333333333
# the average salary at 75 is:142969.16666666666
#
#
#
# cohort: 2011
# the average salary at 25 is:63116.0
# the average salary at 50 is:80682.66666666667
# the average salary at 75 is:99985.0
#
#
#
# -----------------
# -----------------
# degree: Doctoral - Research/Scholarship
# the average salary at 25 is:52047.75
# the average salary at 50 is:78940.375
# the average salary at 75 is:112368.625
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2006
# the average salary at 25 is:55457.0
# the average salary at 50 is:93056.25
# the average salary at 75 is:126488.0
#
#
#
# cohort: 2001
# the average salary at 25 is:52918.333333333336
# the average salary at 50 is:72311.66666666667
# the average salary at 75 is:112570.33333333333
#
#
#
# cohort: 2011
# the average salary at 25 is:35799.0
# the average salary at 50 is:42363.0
# the average salary at 75 is:55286.0
#
#
#
# -----------------
# -----------------
# degree: Baccalaureate
# the average salary at 25 is:50936.931818181816
# the average salary at 50 is:65154.34090909091
# the average salary at 75 is:80144.68181818182
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2004
# the average salary at 25 is:53314.0
# the average salary at 50 is:68696.6
# the average salary at 75 is:84961.1
#
#
#
# cohort: 2001
# the average salary at 25 is:50957.2
# the average salary at 50 is:65629.26666666666
# the average salary at 75 is:82017.33333333333
#
#
#
# cohort: 2007
# the average salary at 25 is:48743.4
# the average salary at 50 is:63326.5
# the average salary at 75 is:77475.5
#
#
#
# cohort: 2013
# the average salary at 25 is:52614.25
# the average salary at 50 is:65461.5
# the average salary at 75 is:78468.75
#
#
#
# cohort: 2010
# the average salary at 25 is:49167.2
# the average salary at 50 is:60055.0
# the average salary at 75 is:71573.0
#
#
#
# -----------------
# -----------------
# degree: Masters
# the average salary at 25 is:57896.22222222222
# the average salary at 50 is:76278.0
# the average salary at 75 is:95960.44444444444
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2006
# the average salary at 25 is:57291.666666666664
# the average salary at 50 is:75501.0
# the average salary at 75 is:94198.66666666667
#
#
#
# cohort: 2001
# the average salary at 25 is:57315.0
# the average salary at 50 is:75492.6
# the average salary at 75 is:95951.6
#
#
#
# cohort: 2011
# the average salary at 25 is:62616.0
# the average salary at 50 is:82536.0
# the average salary at 75 is:101290.0
#
#
#
# -----------------
# ===============
# ===============
# data for: UNIV OF TEXAS HEALTH SCIENCE CENTER
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Doctoral - Professional Practice
# the average salary at 25 is:76919.5
# the average salary at 50 is:117730.5
# the average salary at 75 is:175417.16666666666
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:88536.33333333333
# the average salary at 50 is:136062.83333333334
# the average salary at 75 is:210049.16666666666
#
#
#
# cohort: 2006
# the average salary at 25 is:70800.25
# the average salary at 50 is:110209.25
# the average salary at 75 is:161121.5
#
#
#
# cohort: 2011
# the average salary at 25 is:54307.5
# the average salary at 50 is:77776.0
# the average salary at 75 is:100112.5
#
#
#
# -----------------
# -----------------
# degree: Masters
# the average salary at 25 is:53990.416666666664
# the average salary at 50 is:79559.08333333333
# the average salary at 75 is:119462.91666666667
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:58943.666666666664
# the average salary at 50 is:85936.83333333333
# the average salary at 75 is:128035.16666666667
#
#
#
# cohort: 2006
# the average salary at 25 is:51393.0
# the average salary at 50 is:77794.75
# the average salary at 75 is:121168.5
#
#
#
# cohort: 2011
# the average salary at 25 is:44325.5
# the average salary at 50 is:63954.5
# the average salary at 75 is:90335.0
#
#
#
# -----------------
# -----------------
# degree: Doctoral - Research/Scholarship
# the average salary at 25 is:61591.083333333336
# the average salary at 50 is:81395.33333333333
# the average salary at 75 is:115556.5
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:64368.5
# the average salary at 50 is:85945.5
# the average salary at 75 is:121292.0
#
#
#
# cohort: 2006
# the average salary at 25 is:60110.75
# the average salary at 50 is:78835.75
# the average salary at 75 is:114938.5
#
#
#
# cohort: 2011
# the average salary at 25 is:56219.5
# the average salary at 50 is:72864.0
# the average salary at 75 is:99586.0
#
#
#
# -----------------
# -----------------
# degree: Baccalaureate
# the average salary at 25 is:55218.857142857145
# the average salary at 50 is:71177.85714285714
# the average salary at 75 is:87358.71428571429
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2004
# the average salary at 25 is:59871.0
# the average salary at 50 is:79669.66666666667
# the average salary at 75 is:98730.33333333333
#
#
#
# cohort: 2001
# the average salary at 25 is:60716.0
# the average salary at 50 is:78583.33333333333
# the average salary at 75 is:101044.33333333333
#
#
#
# cohort: 2007
# the average salary at 25 is:52840.75
# the average salary at 50 is:66799.75
# the average salary at 75 is:79636.5
#
#
#
# cohort: 2013
# the average salary at 25 is:53272.5
# the average salary at 50 is:66438.0
# the average salary at 75 is:78593.0
#
#
#
# cohort: 2010
# the average salary at 25 is:46697.5
# the average salary at 50 is:60828.0
# the average salary at 75 is:73983.0
#
#
#
# -----------------
# ===============
# ===============
# data for: UNIV OF TEXAS MEDICAL BRANCH
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Doctoral - Professional Practice
# the average salary at 25 is:76947.14285714286
# the average salary at 50 is:115258.85714285714
# the average salary at 75 is:166423.85714285713
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:96962.33333333333
# the average salary at 50 is:152279.66666666666
# the average salary at 75 is:236444.0
#
#
#
# cohort: 2006
# the average salary at 25 is:70058.0
# the average salary at 50 is:110753.5
# the average salary at 75 is:153015.5
#
#
#
# cohort: 2011
# the average salary at 25 is:53813.5
# the average salary at 50 is:64233.0
# the average salary at 75 is:74802.0
#
#
#
# -----------------
# -----------------
# degree: Doctoral - Research/Scholarship
# the average salary at 25 is:52439.09090909091
# the average salary at 50 is:74913.27272727272
# the average salary at 75 is:103559.81818181818
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:57022.0
# the average salary at 50 is:82819.8
# the average salary at 75 is:114645.4
#
#
#
# cohort: 2006
# the average salary at 25 is:52476.0
# the average salary at 50 is:73750.0
# the average salary at 75 is:101701.75
#
#
#
# cohort: 2011
# the average salary at 25 is:40908.0
# the average salary at 50 is:57473.5
# the average salary at 75 is:79562.0
#
#
#
# -----------------
# -----------------
# degree: Baccalaureate
# the average salary at 25 is:55134.46875
# the average salary at 50 is:68847.03125
# the average salary at 75 is:84284.40625
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:58252.666666666664
# the average salary at 50 is:74777.16666666667
# the average salary at 75 is:91526.08333333333
#
#
#
# cohort: 2004
# the average salary at 25 is:56569.75
# the average salary at 50 is:70524.625
# the average salary at 75 is:87136.5
#
#
#
# cohort: 2007
# the average salary at 25 is:53442.333333333336
# the average salary at 50 is:65153.0
# the average salary at 75 is:78083.83333333333
#
#
#
# cohort: 2013
# the average salary at 25 is:49550.666666666664
# the average salary at 50 is:60936.0
# the average salary at 75 is:74154.0
#
#
#
# cohort: 2010
# the average salary at 25 is:47802.333333333336
# the average salary at 50 is:55952.0
# the average salary at 75 is:70243.66666666667
#
#
#
# -----------------
# -----------------
# degree: Masters
# the average salary at 25 is:67550.83333333333
# the average salary at 50 is:87179.83333333333
# the average salary at 75 is:109429.33333333333
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2006
# the average salary at 25 is:71323.0
# the average salary at 50 is:90074.0
# the average salary at 75 is:111792.0
#
#
#
# cohort: 2001
# the average salary at 25 is:65127.666666666664
# the average salary at 50 is:85557.66666666667
# the average salary at 75 is:108878.66666666667
#
#
#
# cohort: 2011
# the average salary at 25 is:67276.0
# the average salary at 50 is:86258.0
# the average salary at 75 is:106356.0
#
#
#
# -----------------
# ===============
# ===============
# data for: COLORADO SCHOOL OF MINES
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Baccalaureate
# the average salary at 25 is:61252.27777777778
# the average salary at 50 is:82314.93518518518
# the average salary at 75 is:108672.29629629629
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2004
# the average salary at 25 is:66756.08
# the average salary at 50 is:90080.48
# the average salary at 75 is:121031.88
#
#
#
# cohort: 2001
# the average salary at 25 is:62570.04347826087
# the average salary at 50 is:86399.17391304347
# the average salary at 75 is:119205.30434782608
#
#
#
# cohort: 1998
# the average salary at 25 is:68436.09090909091
# the average salary at 50 is:90046.5
# the average salary at 75 is:118705.0
#
#
#
# cohort: 2007
# the average salary at 25 is:57756.88888888889
# the average salary at 50 is:76720.72222222222
# the average salary at 75 is:96962.16666666667
#
#
#
# cohort: 2010
# the average salary at 25 is:48531.6
# the average salary at 50 is:64723.5
# the average salary at 75 is:79681.5
#
#
#
# cohort: 2013
# the average salary at 25 is:47669.9
# the average salary at 50 is:64158.9
# the average salary at 75 is:81544.5
#
#
#
# -----------------
# -----------------
# degree: Masters
# the average salary at 25 is:64269.16129032258
# the average salary at 50 is:88814.70967741935
# the average salary at 75 is:124752.90322580645
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:64415.8
# the average salary at 50 is:96336.6
# the average salary at 75 is:135223.7
#
#
#
# cohort: 1996
# the average salary at 25 is:75573.16666666667
# the average salary at 50 is:105081.5
# the average salary at 75 is:144798.0
#
#
#
# cohort: 2006
# the average salary at 25 is:63065.3
# the average salary at 50 is:80772.5
# the average salary at 75 is:115902.2
#
#
#
# cohort: 2011
# the average salary at 25 is:52818.8
# the average salary at 50 is:70335.2
# the average salary at 75 is:97458.6
#
#
#
# -----------------
# -----------------
# degree: Doctoral - Research/Scholarship
# the average salary at 25 is:72564.21428571429
# the average salary at 50 is:99657.21428571429
# the average salary at 75 is:145733.14285714287
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:79853.5
# the average salary at 50 is:107652.0
# the average salary at 75 is:150059.0
#
#
#
# cohort: 1996
# the average salary at 25 is:86260.5
# the average salary at 50 is:114740.75
# the average salary at 75 is:168809.75
#
#
#
# cohort: 2006
# the average salary at 25 is:60798.75
# the average salary at 50 is:89158.0
# the average salary at 75 is:135714.75
#
#
#
# cohort: 2011
# the average salary at 25 is:54124.0
# the average salary at 50 is:74499.0
# the average salary at 75 is:110965.0
#
#
#
# -----------------
# ===============
# ===============
# data for: UNIVERSITY OF COLORADO DENVER
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Doctoral - Professional Practice
# the average salary at 25 is:75323.11111111111
# the average salary at 50 is:100453.44444444444
# the average salary at 75 is:134088.55555555556
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:88376.2
# the average salary at 50 is:116784.7
# the average salary at 75 is:161744.1
#
#
#
# cohort: 2006
# the average salary at 25 is:67653.9
# the average salary at 50 is:92835.0
# the average salary at 75 is:121491.6
#
#
#
# cohort: 1996
# the average salary at 25 is:77697.0
# the average salary at 50 is:102618.0
# the average salary at 75 is:137604.5
#
#
#
# cohort: 2011
# the average salary at 25 is:63605.8
# the average salary at 50 is:82162.0
# the average salary at 75 is:102565.0
#
#
#
# -----------------
# -----------------
# degree: Masters
# the average salary at 25 is:48331.5503875969
# the average salary at 50 is:65245.83720930233
# the average salary at 75 is:86739.61240310078
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 1996
# the average salary at 25 is:54704.42857142857
# the average salary at 50 is:73736.57142857143
# the average salary at 75 is:98095.17142857143
#
#
#
# cohort: 2001
# the average salary at 25 is:48983.84782608696
# the average salary at 50 is:66455.23913043478
# the average salary at 75 is:88553.82608695653
#
#
#
# cohort: 2006
# the average salary at 25 is:44319.65714285714
# the average salary at 50 is:59703.65714285714
# the average salary at 75 is:79317.14285714286
#
#
#
# cohort: 2011
# the average salary at 25 is:39666.92307692308
# the average salary at 50 is:53028.0
# the average salary at 75 is:69731.0
#
#
#
# -----------------
# -----------------
# degree: Doctoral - Research/Scholarship
# the average salary at 25 is:58490.0
# the average salary at 50 is:79743.55555555556
# the average salary at 75 is:112977.11111111111
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:56380.0
# the average salary at 50 is:92456.5
# the average salary at 75 is:140521.0
#
#
#
# cohort: 2006
# the average salary at 25 is:58996.0
# the average salary at 50 is:76349.25
# the average salary at 75 is:109039.75
#
#
#
# cohort: 2011
# the average salary at 25 is:59222.0
# the average salary at 50 is:75794.0
# the average salary at 75 is:99864.33333333333
#
#
#
# -----------------
# -----------------
# degree: Baccalaureate
# the average salary at 25 is:34105.796875
# the average salary at 50 is:46655.61328125
# the average salary at 75 is:61241.1640625
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2004
# the average salary at 25 is:35285.640625
# the average salary at 50 is:48802.953125
# the average salary at 75 is:64213.15625
#
#
#
# cohort: 1998
# the average salary at 25 is:43114.5
# the average salary at 50 is:57728.425
# the average salary at 75 is:75608.625
#
#
#
# cohort: 2001
# the average salary at 25 is:36518.29090909091
# the average salary at 50 is:50940.2
# the average salary at 75 is:66880.29090909091
#
#
#
# cohort: 2007
# the average salary at 25 is:32646.0
# the average salary at 50 is:43418.5625
# the average salary at 75 is:56082.583333333336
#
#
#
# cohort: 2013
# the average salary at 25 is:24219.043478260868
# the average salary at 50 is:34052.217391304344
# the average salary at 75 is:45367.34782608696
#
#
#
# cohort: 2010
# the average salary at 25 is:23679.653846153848
# the average salary at 50 is:32396.46153846154
# the average salary at 75 is:43458.53846153846
#
#
#
# -----------------
# ===============
# ===============
# data for: UNIVERSITY OF TEXAS AT DALLAS
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Doctoral - Research/Scholarship
# the average salary at 25 is:66463.8
# the average salary at 50 is:93408.46666666666
# the average salary at 75 is:124072.63333333333
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:68076.0
# the average salary at 50 is:105613.55555555556
# the average salary at 75 is:146831.0
#
#
#
# cohort: 2006
# the average salary at 25 is:68024.69230769231
# the average salary at 50 is:90520.07692307692
# the average salary at 75 is:116737.07692307692
#
#
#
# cohort: 2011
# the average salary at 25 is:62113.625
# the average salary at 50 is:84371.375
# the average salary at 75 is:110389.75
#
#
#
# -----------------
# -----------------
# degree: Masters
# the average salary at 25 is:46668.66216216216
# the average salary at 50 is:65997.9054054054
# the average salary at 75 is:90139.27027027027
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:52381.08823529412
# the average salary at 50 is:72958.44117647059
# the average salary at 75 is:100126.82352941176
#
#
#
# cohort: 2006
# the average salary at 25 is:44293.846153846156
# the average salary at 50 is:63386.03846153846
# the average salary at 75 is:85868.53846153847
#
#
#
# cohort: 2011
# the average salary at 25 is:37206.0
# the average salary at 50 is:53944.357142857145
# the average salary at 75 is:73815.14285714286
#
#
#
# -----------------
# -----------------
# degree: Baccalaureate
# the average salary at 25 is:37646.12435233161
# the average salary at 50 is:51391.76683937824
# the average salary at 75 is:67818.8238341969
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:43438.79069767442
# the average salary at 50 is:59617.976744186046
# the average salary at 75 is:79119.79069767441
#
#
#
# cohort: 2004
# the average salary at 25 is:39808.07843137255
# the average salary at 50 is:55339.19607843137
# the average salary at 75 is:73752.43137254902
#
#
#
# cohort: 2007
# the average salary at 25 is:36936.066666666666
# the average salary at 50 is:49234.15555555555
# the average salary at 75 is:64052.71111111111
#
#
#
# cohort: 2013
# the average salary at 25 is:33175.06896551724
# the average salary at 50 is:44407.206896551725
# the average salary at 75 is:58469.34482758621
#
#
#
# cohort: 2010
# the average salary at 25 is:29736.88
# the average salary at 50 is:41175.72
# the average salary at 75 is:53901.0
#
#
#
# -----------------
# -----------------
# degree: Doctoral - Professional Practice
# the average salary at 25 is:50287.0
# the average salary at 50 is:65322.5
# the average salary at 75 is:88847.5
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2006
# the average salary at 25 is:50287.0
# the average salary at 50 is:65322.5
# the average salary at 75 is:88847.5
#
#
#
# -----------------
# ===============
# ===============
# data for: COLORADO STATE UNIVERSITY
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Masters
# the average salary at 25 is:44032.67701863354
# the average salary at 50 is:60000.024844720494
# the average salary at 75 is:80461.26708074534
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 1996
# the average salary at 25 is:48713.688888888886
# the average salary at 50 is:66135.22222222222
# the average salary at 75 is:90050.02222222222
#
#
#
# cohort: 2001
# the average salary at 25 is:45588.65517241379
# the average salary at 50 is:62430.08620689655
# the average salary at 75 is:83519.6724137931
#
#
#
# cohort: 2006
# the average salary at 25 is:40566.0
# the average salary at 50 is:54698.8717948718
# the average salary at 75 is:72193.30769230769
#
#
#
# cohort: 2011
# the average salary at 25 is:35312.05263157895
# the average salary at 50 is:48932.52631578947
# the average salary at 75 is:65385.94736842105
#
#
#
# -----------------
# -----------------
# degree: Doctoral - Research/Scholarship
# the average salary at 25 is:57768.549019607846
# the average salary at 50 is:76951.66666666667
# the average salary at 75 is:101383.58823529411
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 1996
# the average salary at 25 is:69876.25
# the average salary at 50 is:91739.16666666667
# the average salary at 75 is:121389.5
#
#
#
# cohort: 2006
# the average salary at 25 is:54555.666666666664
# the average salary at 50 is:73357.66666666667
# the average salary at 75 is:93351.4
#
#
#
# cohort: 2001
# the average salary at 25 is:57299.05882352941
# the average salary at 50 is:77048.05882352941
# the average salary at 75 is:103572.64705882352
#
#
#
# cohort: 2011
# the average salary at 25 is:45037.42857142857
# the average salary at 50 is:59069.0
# the average salary at 75 is:78983.28571428571
#
#
#
# -----------------
# -----------------
# degree: Baccalaureate
# the average salary at 25 is:32338.641414141413
# the average salary at 50 is:43823.28956228956
# the average salary at 75 is:58022.21548821549
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2004
# the average salary at 25 is:34195.131386861314
# the average salary at 50 is:46160.24087591241
# the average salary at 75 is:61215.18248175183
#
#
#
# cohort: 1998
# the average salary at 25 is:37221.0162601626
# the average salary at 50 is:50859.59349593496
# the average salary at 75 is:67377.76422764227
#
#
#
# cohort: 2001
# the average salary at 25 is:34068.73722627737
# the average salary at 50 is:46398.26277372263
# the average salary at 75 is:61606.6496350365
#
#
#
# cohort: 2007
# the average salary at 25 is:29071.02
# the average salary at 50 is:38999.32
# the average salary at 75 is:51522.24
#
#
#
# cohort: 2013
# the average salary at 25 is:25486.744680851065
# the average salary at 50 is:34050.97872340425
# the average salary at 75 is:44106.59574468085
#
#
#
# cohort: 2010
# the average salary at 25 is:23476.78
# the average salary at 50 is:31889.22
# the average salary at 75 is:42518.12
#
#
#
# -----------------
# -----------------
# degree: Doctoral - Professional Practice
# the average salary at 25 is:48608.0
# the average salary at 50 is:68330.33333333333
# the average salary at 75 is:91446.33333333333
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:52618.666666666664
# the average salary at 50 is:72480.33333333333
# the average salary at 75 is:97212.33333333333
#
#
#
# cohort: 1996
# the average salary at 25 is:49075.0
# the average salary at 50 is:69720.66666666667
# the average salary at 75 is:95579.66666666667
#
#
#
# cohort: 2006
# the average salary at 25 is:47799.0
# the average salary at 50 is:66757.5
# the average salary at 75 is:86769.0
#
#
#
# cohort: 2011
# the average salary at 25 is:36793.0
# the average salary at 50 is:54855.0
# the average salary at 75 is:71103.0
#
#
#
# -----------------
# ===============
# ===============
# data for: UNIVERSITY OF COLORADO-BOULDER
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Doctoral - Research/Scholarship
# the average salary at 25 is:53488.64864864865
# the average salary at 50 is:70954.43243243243
# the average salary at 75 is:95088.06756756757
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:52979.25925925926
# the average salary at 50 is:71016.48148148147
# the average salary at 75 is:95440.62962962964
#
#
#
# cohort: 2006
# the average salary at 25 is:54569.5
# the average salary at 50 is:71314.04166666667
# the average salary at 75 is:94899.29166666667
#
#
#
# cohort: 1996
# the average salary at 25 is:59160.6
# the average salary at 50 is:78744.93333333333
# the average salary at 75 is:105449.06666666667
#
#
#
# cohort: 2011
# the average salary at 25 is:41330.375
# the average salary at 50 is:55059.0
# the average salary at 75 is:75037.625
#
#
#
# -----------------
# -----------------
# degree: Masters
# the average salary at 25 is:44000.36507936508
# the average salary at 50 is:60174.03968253968
# the average salary at 75 is:81223.97619047618
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:43885.31914893617
# the average salary at 50 is:60404.48936170213
# the average salary at 75 is:82220.89361702128
#
#
#
# cohort: 1996
# the average salary at 25 is:51677.31428571429
# the average salary at 50 is:70937.71428571429
# the average salary at 75 is:94108.25714285714
#
#
#
# cohort: 2006
# the average salary at 25 is:40089.9
# the average salary at 50 is:53764.566666666666
# the average salary at 75 is:71943.83333333333
#
#
#
# cohort: 2011
# the average salary at 25 is:33573.78571428572
# the average salary at 50 is:46225.78571428572
# the average salary at 75 is:65552.5
#
#
#
# -----------------
# -----------------
# degree: Baccalaureate
# the average salary at 25 is:34759.84240150094
# the average salary at 50 is:48385.65103189494
# the average salary at 75 is:65785.32082551594
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2004
# the average salary at 25 is:36495.201550387595
# the average salary at 50 is:51505.395348837206
# the average salary at 75 is:70413.28682170542
#
#
#
# cohort: 2001
# the average salary at 25 is:37118.22480620155
# the average salary at 50 is:51818.589147286824
# the average salary at 75 is:70899.11627906977
#
#
#
# cohort: 1998
# the average salary at 25 is:40497.425742574254
# the average salary at 50 is:56062.346534653465
# the average salary at 75 is:76515.28712871287
#
#
#
# cohort: 2007
# the average salary at 25 is:31066.24418604651
# the average salary at 50 is:43188.59302325582
# the average salary at 75 is:58286.6976744186
#
#
#
# cohort: 2010
# the average salary at 25 is:25041.391304347828
# the average salary at 50 is:34336.04347826087
# the average salary at 75 is:45717.086956521736
#
#
#
# cohort: 2013
# the average salary at 25 is:26595.785714285714
# the average salary at 50 is:35828.19047619047
# the average salary at 75 is:47395.0
#
#
#
# -----------------
# -----------------
# degree: Doctoral - Professional Practice
# the average salary at 25 is:55087.3
# the average salary at 50 is:75874.5
# the average salary at 75 is:111069.1
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 1996
# the average salary at 25 is:60883.0
# the average salary at 50 is:85777.66666666667
# the average salary at 75 is:127813.0
#
#
#
# cohort: 2001
# the average salary at 25 is:57373.666666666664
# the average salary at 50 is:80725.33333333333
# the average salary at 75 is:122289.0
#
#
#
# cohort: 2006
# the average salary at 25 is:52119.0
# the average salary at 50 is:69150.0
# the average salary at 75 is:101718.0
#
#
#
# cohort: 2011
# the average salary at 25 is:45932.5
# the average salary at 50 is:60468.0
# the average salary at 75 is:78474.5
#
#
#
# -----------------
# ===============
# ===============
# data for: UNIV OF COLORADO AT COLO SPRINGS
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Masters
# the average salary at 25 is:53051.958333333336
# the average salary at 50 is:70797.16666666667
# the average salary at 75 is:93519.43055555556
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 1996
# the average salary at 25 is:62088.64705882353
# the average salary at 50 is:82039.76470588235
# the average salary at 75 is:107053.76470588235
#
#
#
# cohort: 2001
# the average salary at 25 is:54962.92592592593
# the average salary at 50 is:73686.81481481482
# the average salary at 75 is:98767.18518518518
#
#
#
# cohort: 2006
# the average salary at 25 is:48306.45
# the average salary at 50 is:64240.9
# the average salary at 75 is:84080.85
#
#
#
# cohort: 2011
# the average salary at 25 is:39263.25
# the average salary at 50 is:53544.75
# the average salary at 75 is:70644.25
#
#
#
# -----------------
# -----------------
# degree: Baccalaureate
# the average salary at 25 is:32819.1282051282
# the average salary at 50 is:44400.34871794872
# the average salary at 75 is:58262.67692307692
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 1998
# the average salary at 25 is:38461.42424242424
# the average salary at 50 is:52522.06060606061
# the average salary at 75 is:70079.57575757576
#
#
#
# cohort: 2004
# the average salary at 25 is:34741.14893617021
# the average salary at 50 is:46484.82978723404
# the average salary at 75 is:60951.29787234042
#
#
#
# cohort: 2001
# the average salary at 25 is:36060.59090909091
# the average salary at 50 is:49412.295454545456
# the average salary at 75 is:65055.13636363636
#
#
#
# cohort: 2007
# the average salary at 25 is:29575.657142857144
# the average salary at 50 is:39788.91428571429
# the average salary at 75 is:51427.8
#
#
#
# cohort: 2010
# the average salary at 25 is:23810.42105263158
# the average salary at 50 is:31611.21052631579
# the average salary at 75 is:41486.21052631579
#
#
#
# cohort: 2013
# the average salary at 25 is:24909.235294117647
# the average salary at 50 is:33687.470588235294
# the average salary at 75 is:43132.23529411765
#
#
#
# -----------------
# ===============
# ===============
# data for: UNIVERSITY OF TEXAS-ARLINGTON
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Masters
# the average salary at 25 is:49081.40206185567
# the average salary at 50 is:65380.072164948455
# the average salary at 75 is:85690.03092783505
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:53605.74418604651
# the average salary at 50 is:71127.69767441861
# the average salary at 75 is:93198.72093023256
#
#
#
# cohort: 2006
# the average salary at 25 is:48062.02777777778
# the average salary at 50 is:62853.38888888889
# the average salary at 75 is:81727.02777777778
#
#
#
# cohort: 2011
# the average salary at 25 is:40312.0
# the average salary at 50 is:56703.0
# the average salary at 75 is:75678.61111111111
#
#
#
# -----------------
# -----------------
# degree: Doctoral - Research/Scholarship
# the average salary at 25 is:72941.86956521739
# the average salary at 50 is:93497.60869565218
# the average salary at 75 is:120033.73913043478
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:79643.2
# the average salary at 50 is:99196.5
# the average salary at 75 is:128901.2
#
#
#
# cohort: 2006
# the average salary at 25 is:71598.85714285714
# the average salary at 50 is:89701.0
# the average salary at 75 is:110559.71428571429
#
#
#
# cohort: 2011
# the average salary at 25 is:63339.833333333336
# the average salary at 50 is:88428.83333333333
# the average salary at 75 is:116307.66666666667
#
#
#
# -----------------
# -----------------
# degree: Baccalaureate
# the average salary at 25 is:40458.83661971831
# the average salary at 50 is:52882.05352112676
# the average salary at 75 is:67473.6338028169
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:44088.69902912621
# the average salary at 50 is:57667.87378640777
# the average salary at 75 is:73875.66019417475
#
#
#
# cohort: 2004
# the average salary at 25 is:43047.46534653466
# the average salary at 50 is:56593.10891089109
# the average salary at 75 is:71973.86138613861
#
#
#
# cohort: 2007
# the average salary at 25 is:39560.52112676056
# the average salary at 50 is:51074.32394366197
# the average salary at 75 is:64777.80281690141
#
#
#
# cohort: 2013
# the average salary at 25 is:34642.769230769234
# the average salary at 50 is:44941.5641025641
# the average salary at 75 is:57415.4358974359
#
#
#
# cohort: 2010
# the average salary at 25 is:32051.024390243903
# the average salary at 50 is:42400.87804878049
# the average salary at 75 is:54540.51219512195
#
#
#
# -----------------
# ===============
# ===============
# data for: UNIVERSITY OF TEXAS-SAN ANTONIO
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Doctoral - Research/Scholarship
# the average salary at 25 is:58309.875
# the average salary at 50 is:81171.25
# the average salary at 75 is:98929.375
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2011
# the average salary at 25 is:59587.5
# the average salary at 50 is:82274.0
# the average salary at 75 is:103329.5
#
#
#
# cohort: 2006
# the average salary at 25 is:57032.25
# the average salary at 50 is:80068.5
# the average salary at 75 is:94529.25
#
#
#
# -----------------
# -----------------
# degree: Masters
# the average salary at 25 is:44298.48101265823
# the average salary at 50 is:59122.74683544304
# the average salary at 75 is:76767.88607594937
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:50715.27272727273
# the average salary at 50 is:65902.78787878787
# the average salary at 75 is:85211.30303030302
#
#
#
# cohort: 2006
# the average salary at 25 is:41117.566666666666
# the average salary at 50 is:55597.066666666666
# the average salary at 75 is:72273.43333333333
#
#
#
# cohort: 2011
# the average salary at 25 is:37028.0625
# the average salary at 50 is:51749.5625
# the average salary at 75 is:67780.4375
#
#
#
# -----------------
# -----------------
# degree: Baccalaureate
# the average salary at 25 is:36881.80563380282
# the average salary at 50 is:48653.898591549296
# the average salary at 75 is:62557.681690140846
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:41011.845360824744
# the average salary at 50 is:53757.154639175256
# the average salary at 75 is:68951.9175257732
#
#
#
# cohort: 2004
# the average salary at 25 is:39296.903846153844
# the average salary at 50 is:51763.91346153846
# the average salary at 75 is:67298.71153846153
#
#
#
# cohort: 2007
# the average salary at 25 is:34984.32432432433
# the average salary at 50 is:46200.59459459459
# the average salary at 75 is:58915.75675675676
#
#
#
# cohort: 2013
# the average salary at 25 is:31858.7
# the average salary at 50 is:42382.875
# the average salary at 75 is:53775.525
#
#
#
# cohort: 2010
# the average salary at 25 is:29120.65
# the average salary at 50 is:39002.1
# the average salary at 75 is:50244.7
#
#
#
# -----------------
# ===============
# ===============
# data for: UNIVERSITY OF TEXAS - PAN AMERICAN
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Baccalaureate
# the average salary at 25 is:38845.46945337621
# the average salary at 50 is:48982.75562700965
# the average salary at 75 is:60953.85530546624
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2004
# the average salary at 25 is:41949.515789473684
# the average salary at 50 is:52580.68421052631
# the average salary at 75 is:65038.58947368421
#
#
#
# cohort: 2001
# the average salary at 25 is:43702.03409090909
# the average salary at 50 is:53744.22727272727
# the average salary at 75 is:66378.94318181818
#
#
#
# cohort: 2007
# the average salary at 25 is:37535.82608695652
# the average salary at 50 is:47317.02898550725
# the average salary at 75 is:58521.637681159424
#
#
#
# cohort: 2010
# the average salary at 25 is:28577.46875
# the average salary at 50 is:38022.96875
# the average salary at 75 is:48646.5625
#
#
#
# cohort: 2013
# the average salary at 25 is:27611.37037037037
# the average salary at 50 is:38050.74074074074
# the average salary at 75 is:49701.96296296296
#
#
#
# -----------------
# -----------------
# degree: Doctoral - Research/Scholarship
# the average salary at 25 is:79983.0
# the average salary at 50 is:97568.33333333333
# the average salary at 75 is:120265.66666666667
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2006
# the average salary at 25 is:79197.5
# the average salary at 50 is:99148.5
# the average salary at 75 is:126472.0
#
#
#
# cohort: 2011
# the average salary at 25 is:81554.0
# the average salary at 50 is:94408.0
# the average salary at 75 is:107853.0
#
#
#
# -----------------
# -----------------
# degree: Masters
# the average salary at 25 is:45981.921875
# the average salary at 50 is:59434.546875
# the average salary at 75 is:74772.328125
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:52196.142857142855
# the average salary at 50 is:66975.76190476191
# the average salary at 75 is:85661.76190476191
#
#
#
# cohort: 2006
# the average salary at 25 is:44514.555555555555
# the average salary at 50 is:57321.88888888889
# the average salary at 75 is:71250.66666666667
#
#
#
# cohort: 2011
# the average salary at 25 is:40301.9375
# the average salary at 50 is:53101.8125
# the average salary at 75 is:66422.75
#
#
#
# -----------------
# ===============
# ===============
# data for: UNIVERSITY OF TEXAS-PERMIAN BASIN
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Masters
# the average salary at 25 is:50664.25
# the average salary at 50 is:69181.5
# the average salary at 75 is:97280.0
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:56023.666666666664
# the average salary at 50 is:74649.83333333333
# the average salary at 75 is:98533.0
#
#
#
# cohort: 2006
# the average salary at 25 is:47323.42857142857
# the average salary at 50 is:62930.28571428572
# the average salary at 75 is:88257.71428571429
#
#
#
# cohort: 2011
# the average salary at 25 is:47740.666666666664
# the average salary at 50 is:72831.0
# the average salary at 75 is:115826.0
#
#
#
# -----------------
# -----------------
# degree: Baccalaureate
# the average salary at 25 is:36055.70802919708
# the average salary at 50 is:46190.45255474452
# the average salary at 75 is:59077.97810218978
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2004
# the average salary at 25 is:37337.142857142855
# the average salary at 50 is:47794.28571428572
# the average salary at 75 is:60368.59523809524
#
#
#
# cohort: 2013
# the average salary at 25 is:34638.0
# the average salary at 50 is:46179.545454545456
# the average salary at 75 is:58224.818181818184
#
#
#
# cohort: 2001
# the average salary at 25 is:37619.46153846154
# the average salary at 50 is:47247.05128205128
# the average salary at 75 is:61832.53846153846
#
#
#
# cohort: 2007
# the average salary at 25 is:35656.58064516129
# the average salary at 50 is:45628.87096774193
# the average salary at 75 is:58330.096774193546
#
#
#
# cohort: 2010
# the average salary at 25 is:29852.928571428572
# the average salary at 50 is:39687.642857142855
# the average salary at 75 is:49859.07142857143
#
#
#
# -----------------
# ===============
# ===============
# data for: UNIVERSITY OF TEXAS AT TYLER
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Masters
# the average salary at 25 is:49108.67567567567
# the average salary at 50 is:64551.32432432433
# the average salary at 75 is:84543.43243243243
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2006
# the average salary at 25 is:48395.0
# the average salary at 50 is:64686.36363636364
# the average salary at 75 is:86824.36363636363
#
#
#
# cohort: 2001
# the average salary at 25 is:50503.0
# the average salary at 50 is:66203.6875
# the average salary at 75 is:86463.25
#
#
#
# cohort: 2011
# the average salary at 25 is:47662.8
# the average salary at 50 is:61759.0
# the average salary at 75 is:78962.7
#
#
#
# -----------------
# -----------------
# degree: Baccalaureate
# the average salary at 25 is:36624.90683229814
# the average salary at 50 is:47978.068322981366
# the average salary at 75 is:62885.776397515525
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2007
# the average salary at 25 is:35577.305555555555
# the average salary at 50 is:46610.916666666664
# the average salary at 75 is:59560.194444444445
#
#
#
# cohort: 2001
# the average salary at 25 is:39639.230769230766
# the average salary at 50 is:52576.1282051282
# the average salary at 75 is:69996.23076923077
#
#
#
# cohort: 2004
# the average salary at 25 is:37552.48
# the average salary at 50 is:49049.54
# the average salary at 75 is:65787.4
#
#
#
# cohort: 2010
# the average salary at 25 is:31480.5
# the average salary at 50 is:41084.3
# the average salary at 75 is:51963.4
#
#
#
# cohort: 2013
# the average salary at 25 is:35166.4375
# the average salary at 50 is:45115.25
# the average salary at 75 is:57622.0
#
#
#
# -----------------
# ===============
# ===============
# data for: UNIVERSITY OF TEXAS-EL PASO
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Masters
# the average salary at 25 is:45104.893939393936
# the average salary at 50 is:61678.469696969696
# the average salary at 75 is:83833.80303030302
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:48415.46666666667
# the average salary at 50 is:65619.13333333333
# the average salary at 75 is:89631.23333333334
#
#
#
# cohort: 2006
# the average salary at 25 is:46076.0
# the average salary at 50 is:61521.545454545456
# the average salary at 75 is:82499.04545454546
#
#
#
# cohort: 2011
# the average salary at 25 is:36484.78571428572
# the average salary at 50 is:53480.78571428572
# the average salary at 75 is:73508.21428571429
#
#
#
# -----------------
# -----------------
# degree: Baccalaureate
# the average salary at 25 is:37092.18032786885
# the average salary at 50 is:49417.688524590165
# the average salary at 75 is:62990.89180327869
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:41713.11235955056
# the average salary at 50 is:54999.191011235955
# the average salary at 75 is:69247.44943820225
#
#
#
# cohort: 2004
# the average salary at 25 is:41927.5
# the average salary at 50 is:54756.688888888886
# the average salary at 75 is:68446.45555555556
#
#
#
# cohort: 2007
# the average salary at 25 is:33384.52173913043
# the average salary at 50 is:45938.30434782609
# the average salary at 75 is:59160.02898550725
#
#
#
# cohort: 2013
# the average salary at 25 is:27062.185185185186
# the average salary at 50 is:36950.07407407407
# the average salary at 75 is:50532.40740740741
#
#
#
# cohort: 2010
# the average salary at 25 is:26432.066666666666
# the average salary at 50 is:36065.666666666664
# the average salary at 75 is:48086.7
#
#
#
# -----------------
# -----------------
# degree: Doctoral - Research/Scholarship
# the average salary at 25 is:56457.5
# the average salary at 50 is:77927.2
# the average salary at 75 is:101595.2
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2006
# the average salary at 25 is:56928.333333333336
# the average salary at 50 is:76796.33333333333
# the average salary at 75 is:103919.33333333333
#
#
#
# cohort: 2001
# the average salary at 25 is:57364.166666666664
# the average salary at 50 is:79163.16666666667
# the average salary at 75 is:100743.16666666667
#
#
#
# cohort: 2011
# the average salary at 25 is:49605.0
# the average salary at 50 is:73904.0
# the average salary at 75 is:99735.0
#
#
#
# -----------------
# -----------------
# degree: Doctoral - Professional Practice
# the average salary at 25 is:60585.0
# the average salary at 50 is:74265.0
# the average salary at 75 is:97404.0
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2011
# the average salary at 25 is:60585.0
# the average salary at 50 is:74265.0
# the average salary at 75 is:97404.0
#
#
#
# -----------------
# ===============
# ===============
# data for: ARAPAHOE COMMUNITY COLLEGE
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Certificate, <1 year
# the average salary at 25 is:34198.47619047619
# the average salary at 50 is:46577.88888888889
# the average salary at 75 is:62746.666666666664
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2011
# ...
# the average salary at 75 is:53366.21428571428
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 1996
# the average salary at 25 is:34384.53846153846
# the average salary at 50 is:46432.346153846156
# the average salary at 75 is:62228.230769230766
#
#
#
# cohort: 2001
# the average salary at 25 is:29615.484848484848
# the average salary at 50 is:40722.42424242424
# the average salary at 75 is:54653.30303030303
#
#
#
# cohort: 2006
# the average salary at 25 is:26791.92
# the average salary at 50 is:36218.76
# the average salary at 75 is:50007.0
#
#
#
# cohort: 2011
# the average salary at 25 is:23315.0
# the average salary at 50 is:31512.14285714286
# the average salary at 75 is:39872.92857142857
#
#
#
# -----------------
# ===============
# ===============
# data for: PIKES PEAK COMMUNITY COLLEGE
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Certificate, <1 year
# the average salary at 25 is:24388.87037037037
# the average salary at 50 is:35765.81481481482
# the average salary at 75 is:48516.88888888889
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 1996
# the average salary at 25 is:43639.0
# the average salary at 50 is:69329.0
# the average salary at 75 is:85304.33333333333
#
#
#
# cohort: 2001
# the average salary at 25 is:23102.136363636364
# the average salary at 50 is:33590.09090909091
# the average salary at 75 is:46691.72727272727
#
#
#
# cohort: 2006
# the average salary at 25 is:25107.85
# the average salary at 50 is:37313.9
# the average salary at 75 is:50683.4
#
#
#
# cohort: 2011
# the average salary at 25 is:19519.777777777777
# the average salary at 50 is:26456.333333333332
# the average salary at 75 is:35901.444444444445
#
#
#
# -----------------
# -----------------
# degree: Certificate,1-2 years
# the average salary at 25 is:24619.695652173912
# the average salary at 50 is:32674.478260869564
# the average salary at 75 is:41964.04347826087
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:28647.428571428572
# the average salary at 50 is:38145.28571428572
# the average salary at 75 is:48368.28571428572
#
#
#
# cohort: 2011
# the average salary at 25 is:20423.5
# the average salary at 50 is:26675.333333333332
# the average salary at 75 is:36435.0
#
#
#
# cohort: 2006
# the average salary at 25 is:24130.25
# the average salary at 50 is:31845.375
# the average salary at 75 is:40408.0
#
#
#
# cohort: 1996
# the average salary at 25 is:25069.0
# the average salary at 50 is:34840.5
# the average salary at 75 is:42360.5
#
#
#
# -----------------
# -----------------
# degree: Associates
# the average salary at 25 is:30047.394495412846
# the average salary at 50 is:40953.8256880734
# the average salary at 75 is:54242.266055045875
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2006
# the average salary at 25 is:25985.266666666666
# the average salary at 50 is:36144.566666666666
# the average salary at 75 is:46904.4
#
#
#
# cohort: 2001
# the average salary at 25 is:30709.585365853658
# the average salary at 50 is:40967.70731707317
# the average salary at 75 is:53743.634146341465
#
#
#
# cohort: 2011
# the average salary at 25 is:22725.0
# the average salary at 50 is:30732.866666666665
# the average salary at 75 is:41802.2
#
#
#
# cohort: 1996
# the average salary at 25 is:38940.86956521739
# the average salary at 50 is:53867.86956521739
# the average salary at 75 is:72815.34782608696
#
#
#
# -----------------
# ===============
# ===============
# data for: COMMUNITY COLLEGE OF DENVER
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Certificate, <1 year
# the average salary at 25 is:23132.678571428572
# the average salary at 50 is:31614.464285714286
# the average salary at 75 is:43060.392857142855
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2011
# the average salary at 25 is:18877.0
# the average salary at 50 is:26306.666666666668
# the average salary at 75 is:37027.666666666664
#
#
#
# cohort: 1996
# the average salary at 25 is:26947.5
# the average salary at 50 is:34866.25
# the average salary at 75 is:42500.25
#
#
#
# cohort: 2001
# the average salary at 25 is:23873.30769230769
# the average salary at 50 is:33160.692307692305
# the average salary at 75 is:46452.846153846156
#
#
#
# cohort: 2006
# the average salary at 25 is:21617.625
# the average salary at 50 is:29466.375
# the average salary at 75 is:40090.0
#
#
#
# -----------------
# -----------------
# degree: Certificate,1-2 years
# the average salary at 25 is:30482.29268292683
# the average salary at 50 is:41415.68292682927
# the average salary at 75 is:54728.65853658537
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 1996
# the average salary at 25 is:28990.875
# the average salary at 50 is:38558.125
# the average salary at 75 is:49934.0
#
#
#
# cohort: 2001
# the average salary at 25 is:34961.375
# the average salary at 50 is:47653.0625
# the average salary at 75 is:63967.625
#
#
#
# cohort: 2011
# the average salary at 25 is:23566.666666666668
# the average salary at 50 is:31994.666666666668
# the average salary at 75 is:42156.0
#
#
#
# cohort: 2006
# the average salary at 25 is:25973.0
# the average salary at 50 is:37113.333333333336
# the average salary at 75 is:49163.5
#
#
#
# -----------------
# -----------------
# degree: Associates
# the average salary at 25 is:36723.48
# the average salary at 50 is:48939.82
# the average salary at 75 is:63702.22
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:38720.380952380954
# the average salary at 50 is:51680.142857142855
# the average salary at 75 is:68480.52380952382
#
#
#
# cohort: 1996
# the average salary at 25 is:39893.833333333336
# the average salary at 50 is:53969.916666666664
# the average salary at 75 is:70733.25
#
#
#
# cohort: 2011
# the average salary at 25 is:27226.14285714286
# the average salary at 50 is:37276.28571428572
# the average salary at 75 is:47526.57142857143
#
#
#
# cohort: 2006
# the average salary at 25 is:35373.7
# the average salary at 50 is:45313.5
# the average salary at 75 is:56553.5
#
#
#
# -----------------
# ===============
# ===============
# data for: RED ROCKS COMMUNITY COLLEGE
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Certificate, <1 year
# the average salary at 25 is:28069.907894736843
# the average salary at 50 is:39480.28947368421
# the average salary at 75 is:54214.36842105263
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2011
# the average salary at 25 is:21572.823529411766
# the average salary at 50 is:31495.70588235294
# the average salary at 75 is:43912.41176470588
#
#
#
# cohort: 2006
# the average salary at 25 is:25419.7
# the average salary at 50 is:36618.5
# the average salary at 75 is:51490.95
#
#
#
# cohort: 2001
# the average salary at 25 is:30339.333333333332
# the average salary at 50 is:42431.96666666667
# the average salary at 75 is:58032.4
#
#
#
# cohort: 1996
# the average salary at 25 is:38666.77777777778
# the average salary at 50 is:51082.88888888889
# the average salary at 75 is:66998.88888888889
#
#
#
# -----------------
# -----------------
# degree: Certificate,1-2 years
# the average salary at 25 is:39612.93939393939
# the average salary at 50 is:54823.36363636364
# the average salary at 75 is:71907.15151515152
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2011
# the average salary at 25 is:34434.25
# the average salary at 50 is:45138.75
# the average salary at 75 is:57638.75
#
#
#
# cohort: 1996
# the average salary at 25 is:37087.333333333336
# the average salary at 50 is:55512.0
# the average salary at 75 is:73541.33333333333
#
#
#
# cohort: 2001
# the average salary at 25 is:39902.8125
# the average salary at 50 is:54263.1875
# the average salary at 75 is:72339.0
#
#
#
# cohort: 2006
# the average salary at 25 is:49314.75
# the average salary at 50 is:65199.25
# the average salary at 75 is:80771.25
#
#
#
# -----------------
# -----------------
# degree: Associates
# the average salary at 25 is:35403.68656716418
# the average salary at 50 is:50224.05970149254
# the average salary at 75 is:68613.41791044777
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 1996
# the average salary at 25 is:38854.23529411765
# the average salary at 50 is:53651.58823529412
# the average salary at 75 is:73729.76470588235
#
#
#
# cohort: 2006
# the average salary at 25 is:32472.8125
# the average salary at 50 is:48037.125
# the average salary at 75 is:66767.75
#
#
#
# cohort: 2011
# the average salary at 25 is:26523.555555555555
# the average salary at 50 is:38036.555555555555
# the average salary at 75 is:52381.555555555555
#
#
#
# cohort: 2001
# the average salary at 25 is:38129.92
# the average salary at 50 is:53680.48
# the average salary at 75 is:72159.0
#
#
#
# -----------------
# ===============
# ===============
# data for: MORGAN COMMUNITY COLLEGE
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Certificate, <1 year
# the average salary at 25 is:24220.625
# the average salary at 50 is:35564.291666666664
# the average salary at 75 is:51112.5
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:26532.545454545456
# the average salary at 50 is:38703.454545454544
# the average salary at 75 is:56351.09090909091
#
#
#
# cohort: 2006
# the average salary at 25 is:21847.0
# the average salary at 50 is:32830.333333333336
# the average salary at 75 is:49485.333333333336
#
#
#
# cohort: 2011
# the average salary at 25 is:19436.666666666668
# the average salary at 50 is:28471.333333333332
# the average salary at 75 is:38150.0
#
#
#
# cohort: 1996
# the average salary at 25 is:25011.25
# the average salary at 50 is:36352.25
# the average salary at 75 is:48869.0
#
#
#
# -----------------
# -----------------
# degree: Certificate,1-2 years
# the average salary at 25 is:31049.636363636364
# the average salary at 50 is:42448.454545454544
# the average salary at 75 is:56388.90909090909
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 1996
# the average salary at 25 is:23775.0
# the average salary at 50 is:36668.0
# the average salary at 75 is:52184.5
#
#
#
# cohort: 2001
# the average salary at 25 is:34035.8
# the average salary at 50 is:47921.6
# the average salary at 75 is:65589.0
#
#
#
# cohort: 2006
# the average salary at 25 is:33153.333333333336
# the average salary at 50 is:41303.0
# the average salary at 75 is:50149.0
#
#
#
# cohort: 2011
# the average salary at 25 is:24357.0
# the average salary at 50 is:30080.0
# the average salary at 75 is:37517.0
#
#
#
# -----------------
# -----------------
# degree: Associates
# the average salary at 25 is:32545.08695652174
# the average salary at 50 is:42470.565217391304
# the average salary at 75 is:54358.913043478264
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 1996
# the average salary at 25 is:32500.428571428572
# the average salary at 50 is:42256.57142857143
# the average salary at 75 is:55102.0
#
#
#
# cohort: 2001
# the average salary at 25 is:36120.666666666664
# the average salary at 50 is:46198.0
# the average salary at 75 is:59390.666666666664
#
#
#
# cohort: 2006
# the average salary at 25 is:31441.14285714286
# the average salary at 50 is:41733.857142857145
# the average salary at 75 is:52516.142857142855
#
#
#
# cohort: 2011
# the average salary at 25 is:28074.0
# the average salary at 50 is:37234.0
# the average salary at 75 is:46861.333333333336
#
#
#
# -----------------
# ===============
# ===============
# data for: PICKENS TECHNICAL COLLEGE
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Certificate, <1 year
# the average salary at 25 is:20873.125
# the average salary at 50 is:30102.375
# the average salary at 75 is:44648.625
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2011
# the average salary at 25 is:20873.125
# the average salary at 50 is:30102.375
# the average salary at 75 is:44648.625
#
#
#
# -----------------
# -----------------
# degree: Certificate,1-2 years
# the average salary at 25 is:26951.727272727272
# the average salary at 50 is:37267.454545454544
# the average salary at 75 is:52689.90909090909
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:26951.727272727272
# the average salary at 50 is:37267.454545454544
# the average salary at 75 is:52689.90909090909
#
#
#
# -----------------
# ===============
# ===============
# data for: PUEBLO COMMUNITY COLLEGE
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Certificate, <1 year
# the average salary at 25 is:21293.105263157893
# the average salary at 50 is:29285.526315789473
# the average salary at 75 is:39594.65789473684
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2011
# the average salary at 25 is:19248.69230769231
# the average salary at 50 is:26258.69230769231
# the average salary at 75 is:36279.307692307695
#
#
#
# cohort: 2006
# the average salary at 25 is:22464.25
# the average salary at 50 is:31585.9375
# the average salary at 75 is:41594.3125
#
#
#
# cohort: 2001
# the average salary at 25 is:22164.11111111111
# the average salary at 50 is:29568.0
# the average salary at 75 is:40828.555555555555
#
#
#
# -----------------
# -----------------
# degree: Certificate,1-2 years
# the average salary at 25 is:27514.577777777777
# the average salary at 50 is:36300.444444444445
# the average salary at 75 is:47809.177777777775
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2011
# the average salary at 25 is:21093.666666666668
# the average salary at 50 is:27472.833333333332
# the average salary at 75 is:35295.5
#
#
#
# cohort: 2001
# the average salary at 25 is:30250.70588235294
# the average salary at 50 is:39882.64705882353
# the average salary at 75 is:51229.470588235294
#
#
#
# cohort: 2006
# the average salary at 25 is:24623.666666666668
# the average salary at 50 is:32970.73333333333
# the average salary at 75 is:43811.933333333334
#
#
#
# cohort: 1996
# the average salary at 25 is:32568.14285714286
# the average salary at 50 is:42302.42857142857
# the average salary at 75 is:58794.28571428572
#
#
#
# -----------------
# -----------------
# degree: Associates
# the average salary at 25 is:28971.394366197183
# the average salary at 50 is:39320.05633802817
# the average salary at 75 is:51402.35211267605
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:29167.433333333334
# the average salary at 50 is:38973.7
# the average salary at 75 is:50774.166666666664
#
#
#
# cohort: 2006
# the average salary at 25 is:27175.5625
# the average salary at 50 is:37401.125
# the average salary at 75 is:49048.625
#
#
#
# cohort: 1996
# the average salary at 25 is:31247.21052631579
# the average salary at 50 is:42891.21052631579
# the average salary at 75 is:55875.73684210526
#
#
#
# cohort: 2011
# the average salary at 25 is:25573.333333333332
# the average salary at 50 is:34860.333333333336
# the average salary at 75 is:46654.166666666664
#
#
#
# -----------------
# ===============
# ===============
# data for: COMMUNITY COLLEGE OF AURORA
#
# ~DEGREE BREAKDOWN!:
#
# -----------------
# degree: Certificate, <1 year
# the average salary at 25 is:36794.80487804878
# the average salary at 50 is:50139.21951219512
# the average salary at 75 is:64820.48780487805
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:40875.47619047619
# the average salary at 50 is:54607.666666666664
# the average salary at 75 is:68808.38095238095
#
#
#
# cohort: 2011
# the average salary at 25 is:21583.8
# the average salary at 50 is:32795.8
# the average salary at 75 is:43022.0
#
#
#
# cohort: 2006
# the average salary at 25 is:26742.545454545456
# the average salary at 50 is:38730.72727272727
# the average salary at 75 is:56405.90909090909
#
#
#
# cohort: 1996
# the average salary at 25 is:62028.75
# the average salary at 50 is:79732.5
# the average salary at 75 is:94272.25
#
#
#
# -----------------
# -----------------
# degree: Certificate,1-2 years
# the average salary at 25 is:31129.5
# the average salary at 50 is:40842.3
# the average salary at 75 is:52217.6
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 2001
# the average salary at 25 is:29636.428571428572
# the average salary at 50 is:40707.57142857143
# the average salary at 75 is:49759.42857142857
#
#
#
# cohort: 2006
# the average salary at 25 is:30542.125
# the average salary at 50 is:39824.375
# the average salary at 75 is:52845.125
#
#
#
# cohort: 1996
# the average salary at 25 is:37324.0
# the average salary at 50 is:46820.0
# the average salary at 75 is:57656.5
#
#
#
# cohort: 2011
# the average salary at 25 is:32050.0
# the average salary at 50 is:39886.0
# the average salary at 75 is:52654.0
#
#
#
# -----------------
# -----------------
# degree: Associates
# the average salary at 25 is:31623.86046511628
# the average salary at 50 is:43818.023255813954
# the average salary at 75 is:58300.3023255814
#
#
#
#
# ~COHORT BREAKDOWN:
#
# cohort: 1996
# the average salary at 25 is:36998.77777777778
# the average salary at 50 is:47971.22222222222
# the average salary at 75 is:64962.666666666664
#
#
#
# cohort: 2001
# the average salary at 25 is:30414.6
# the average salary at 50 is:43579.0
# the average salary at 75 is:58456.6
#
#
#
# cohort: 2006
# the average salary at 25 is:31184.9
# the average salary at 50 is:42698.4
# the average salary at 75 is:55637.4
#
#
#
# cohort: 2011
# the average salary at 25 is:26674.0
# the average salary at 50 is:38467.5
# the average salary at 75 is:49185.75
#
#
#
# -----------------
# ===============

# %%
bsavg_earnings_csv = "Average Earnings per Institute BS.csv"

bsavg_earnings_df = pd.read_csv(bsavg_earnings_csv)

# %%
bsavg_earningsclean_df = bsavg_earnings_df.dropna(how='any')

# %%
bsavg_earningsclean_df
# Out:
#                                  INSTITUTION  AVERAGE EARNINGS     DEGREE
# 0                   COLORADO SCHOOL OF MINES       84079.83642  BACHELORS
# 1        UNIV OF TEXAS HEALTH SCIENCE CENTER       71251.80952  BACHELORS
# 2               UNIV OF TEXAS MEDICAL BRANCH       69421.96875  BACHELORS
# 3               UT HEALTH CENTER-SAN ANTONIO       65411.98485  BACHELORS
# 4         UNIV OF TEXAS SOUTHWESTERN MED CTR       63203.93939  BACHELORS
# 5          UNIV OF TX MD ANDERSON CANCER CTR       62604.27273  BACHELORS
# 6                 UNIVERSITY OF TEXAS-AUSTIN       60645.90947  BACHELORS
# 7   COLORADO STATE UNIVERSITY - GLOBAL CAMPU       54912.13889  BACHELORS
# 8              UNIVERSITY OF TEXAS-ARLINGTON       53604.84131  BACHELORS
# 9              UNIVERSITY OF TEXAS AT DALLAS       52285.57168  BACHELORS
# 10               UNIVERSITY OF TEXAS-EL PASO       49833.58689  BACHELORS
# 11            UNIVERSITY OF COLORADO-BOULDER       49643.60475  BACHELORS
# 12        UNIVERSITY OF TEXAS - PAN AMERICAN       49594.02680  BACHELORS
# 13           UNIVERSITY OF TEXAS-SAN ANTONIO       49364.46197  BACHELORS
# 14              UNIVERSITY OF TEXAS AT TYLER       49162.91718  BACHELORS
# 15             UNIVERSITY OF COLORADO DENVER       47334.19141  BACHELORS
# 16         UNIVERSITY OF TEXAS-PERMIAN BASIN       47108.04623  BACHELORS
# 17          UNIV OF COLORADO AT COLO SPRINGS       45160.71795  BACHELORS
# 18   METROPOLITAN STATE UNIVERSITY OF DENVER       44844.54090  BACHELORS
# 19                 COLORADO STATE UNIVERSITY       44728.04882  BACHELORS
# 20         UNIVERSITY OF TEXAS - BROWNSVILLE       44295.40873  BACHELORS
# 21                  COLORADO MESA UNIVERSITY       41188.48667  BACHELORS
# 22          COLORADO STATE UNIVERSITY-PUEBLO       41169.71739  BACHELORS
# 23           UNIVERSITY OF NORTHERN COLORADO       39033.50547  BACHELORS
# 24                       ADAMS STATE COLLEGE       38073.20202  BACHELORS
# 25                        FORT LEWIS COLLEGE       37970.77708  BACHELORS
# 26         WESTERN STATE COLORADO UNIVERSITY       37764.37669  BACHELORS
# 27                 COLORADO MOUNTAIN COLLEGE       29741.00000  BACHELORS

# %%
msavg_earnings_csv = "Average Earnings per Institute MS .csv"

msavg_earnings_df = pd.read_csv(msavg_earnings_csv)

# %%
msavg_earningsclean_df = msavg_earnings_df.dropna(how='any')

# %%
msavg_earningsclean_df
# Out:
#                                  INSTITUTION  AVERAGE EARNINGS   DEGREE
# 0                   COLORADO SCHOOL OF MINES       92612.25806  MASTERS
# 1               UNIV OF TEXAS MEDICAL BRANCH       88053.33333  MASTERS
# 2        UNIV OF TEXAS HEALTH SCIENCE CENTER       84337.47222  MASTERS
# 3         UNIV OF TEXAS SOUTHWESTERN MED CTR       80215.16667  MASTERS
# 4               UT HEALTH CENTER-SAN ANTONIO       76711.55556  MASTERS
# 5           UNIV OF COLORADO AT COLO SPRINGS       72456.18519  MASTERS
# 6          UNIVERSITY OF TEXAS-PERMIAN BASIN       72375.25000  MASTERS
# 7              UNIVERSITY OF TEXAS AT DALLAS       67601.94595  MASTERS
# 8              UNIVERSITY OF COLORADO DENVER       66772.33333  MASTERS
# 9              UNIVERSITY OF TEXAS-ARLINGTON       66717.16838  MASTERS
# 10                UNIVERSITY OF TEXAS-AUSTIN       66482.94309  MASTERS
# 11              UNIVERSITY OF TEXAS AT TYLER       66067.81081  MASTERS
# 12  COLORADO STATE UNIVERSITY - GLOBAL CAMPU       65668.13333  MASTERS
# 13               UNIVERSITY OF TEXAS-EL PASO       63539.05556  MASTERS
# 14            UNIVERSITY OF COLORADO-BOULDER       61799.46032  MASTERS
# 15          COLORADO STATE UNIVERSITY-PUEBLO       61632.35897  MASTERS
# 16                 COLORADO STATE UNIVERSITY       61497.98965  MASTERS
# 17           UNIVERSITY OF TEXAS-SAN ANTONIO       60063.03797  MASTERS
# 18        UNIVERSITY OF TEXAS - PAN AMERICAN       60062.93229  MASTERS
# 19         UNIVERSITY OF TEXAS - BROWNSVILLE       59792.35185  MASTERS
# 20                  COLORADO MESA UNIVERSITY       56107.20833  MASTERS
# 21           UNIVERSITY OF NORTHERN COLORADO       51843.97076  MASTERS
# 22                       ADAMS STATE COLLEGE       48390.25926  MASTERS
# 23   METROPOLITAN STATE UNIVERSITY OF DENVER       42821.77778  MASTERS
# 24         WESTERN STATE COLORADO UNIVERSITY       39225.33333  MASTERS

# %%
dravg_earnings_csv = "Average Earnings per Institute Doctoral.csv"

dravg_earnings_df = pd.read_csv(dravg_earnings_csv)

# %%
dravg_earnings_df
# Out:
#                             INSTITUTION  AVERAGE EARNINGS    DEGREE
# 0              COLORADO SCHOOL OF MINES      105984.85710  DOCTORAL
# 1          UT HEALTH CENTER-SAN ANTONIO      105270.88410  DOCTORAL
# 2   UNIV OF TEXAS HEALTH SCIENCE CENTER      104768.34720  DOCTORAL
# 3    UNIVERSITY OF TEXAS - PAN AMERICAN       99272.33333  DOCTORAL
# 4         UNIVERSITY OF COLORADO DENVER       98400.50000  DOCTORAL
# 5         UNIVERSITY OF TEXAS-ARLINGTON       95491.07246  DOCTORAL
# 6    UNIV OF TEXAS SOUTHWESTERN MED CTR       93592.44444  DOCTORAL
# 7          UNIV OF TEXAS MEDICAL BRANCH       93526.72222  DOCTORAL
# 8         UNIVERSITY OF TEXAS AT DALLAS       92992.30208  DOCTORAL
# 9            UNIVERSITY OF TEXAS-AUSTIN       90572.86486  DOCTORAL
# 10      UNIVERSITY OF TEXAS-SAN ANTONIO       79470.16667  DOCTORAL
# 11          UNIVERSITY OF TEXAS-EL PASO       78547.06061  DOCTORAL
# 12            COLORADO STATE UNIVERSITY       77315.31111  DOCTORAL
# 13       UNIVERSITY OF COLORADO-BOULDER       74069.89683  DOCTORAL
# 14      UNIVERSITY OF NORTHERN COLORADO       67152.91304  DOCTORAL

# %%
bsavg_earnings = "Average Earnings per Institute BS.csv"

bsavg_earnings_df = pd.read_csv(bsavg_earnings)
bsavg_earnings_df.dtypes
# Out:
# INSTITUTION          object
# AVERAGE EARNINGS    float64
# DEGREE               object
# dtype: object

# %%
bsavg_earningsclean_df.plot(kind="bar", x="INSTITUTION", y="AVERAGE EARNINGS", title = "Average Earnings (TX & CO)")
plt.show()

# %%
msavg_earningsclean_df.plot(kind="bar", x="INSTITUTION", y="AVERAGE EARNINGS", title = "Average Earnings (TX & CO)")
plt.show()

# %%
dravg_earnings_df.plot(kind="bar", x="INSTITUTION", y="AVERAGE EARNINGS", title = "Average Earnings (TX & CO)")
plt.show()
