# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import csv

# %%
field = []
earning = []
with open('BATX.csv') as csvfile: #open this file, csvfile is temp once indent is finished no longer in csvfile
    reader = csv.reader(csvfile) #red is the name of file, reader will show the csvfile
    next(reader)
    for row in reader:
        field.append(row[5])
        earning.append(int(row[9]))

# %%
print(field)
# Out:
# ['PETROLEUM ENGINEERING', 'BUSINESS/COMMERCE, GENERAL', 'FINANCE AND FINANCIAL MANAGEMENT SERVICES', 'ALLIED HEALTH DIAGNOSTIC, INTERVENTION, AND TREATMENT PROFESSIONS', 'CHEMICAL ENGINEERING', 'ELECTRICAL, ELECTRONICS AND COMMUNICATIONS ENGINEERING']

# %%
print(earning)
# Out:
# [319269, 162153, 127706, 123824, 123591, 120565]

# %%
x = np.arange(len(field))
print(x)
# Out:
# [0 1 2 3 4 5]

# %%
plt.figure()
plt.bar(x, earning)
plt.xticks(x, field, rotation='vertical')

plt.title("TX Top 6 Bachelors Average Earnings")
plt.xlabel("Programs")
plt.ylabel("Average Earnings ($)")
# Out:
# Text(0, 0.5, 'Average Earnings ($)')

# %%
plt.savefig("TX Highest Earning Bachelor Degrees.png")
