# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import csv

# %%
field = []
earning = []
with open('BATX.csv') as csvfile: #open this file, csvfile is temp once indent is finished no longer in csvfile
    reader = csv.reader(csvfile) #red is the name of file, reader will show the csvfile
    next(reader)
    for row in reader:
        field.append(row[5])
        earning.append(int(row[9]))

# %%
print(field)
# Out:
# ['PETROLEUM ENGINEERING', 'BUSINESS/COMMERCE', 'FINANCE*', 'ALLIED HEALTH DIAGNOSTIC*', 'CHEMICAL ENGINEERING', 'ELECTRICAL ENGINEERING*']

# %%
print(earning)
# Out:
# [319269, 162153, 127706, 123824, 123591, 120565]

# %%
x = np.arange(len(field))
print(x)
# Out:
# [0 1 2 3 4 5]

# %%
plt.figure()
plt.bar(x,earning)
plt.xticks(x, field, rotation='vertical')

plt.title("TX Highest Earning Bachelor Degrees")
plt.xlabel("Program")
plt.ylabel("Average Earnings($)")
# Out:
# Text(0, 0.5, 'Average Earnings($)')

# %%
plt.savefig('TX_BA.png')
