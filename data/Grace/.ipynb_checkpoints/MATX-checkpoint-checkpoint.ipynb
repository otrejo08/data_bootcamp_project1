# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import csv

# %%
field = []
earning = []
with open('MATX.csv') as csvfile: #open this file, csvfile is temp once indent is finished no longer in csvfile
    reader = csv.reader(csvfile) #red is the name of file, reader will show the csvfile
    next(reader)
    for row in reader:
        field.append(row[5])
        earning.append(int(row[9]))

# %%
print(field)
# Out:
# ['BUSINESS MANAGEMENT', 'INFORMATION SCIENCES ', 'ENGINEERING', 'HEALTH PROFESSIONS*', 'MULTI/INTERDISCIPLINARY STUDIES', 'MATHEMATICS*']

# %%
print(earning)
# Out:
# [160558, 158779, 132844, 110567, 108092, 107256]

# %%
x = np.arange(len(field))
print(x)
# Out:
# [0 1 2 3 4 5]

# %%
plt.figure()
plt.bar(x,earning)
plt.xticks(x, field, rotation='vertical')

plt.title("TX Highest Earnings Masters Degrees")
plt.xlabel("Program")
plt.ylabel("Average Earnings($)")
# Out:
# Text(0, 0.5, 'Average Earnings($)')
